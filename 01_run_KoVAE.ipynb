# %%
# Install micromamba
# !curl -Ls https://micromamba.snakepit.net/api/micromamba/linux-64/latest | tar -xvj bin/micromamba

# Create a folder to accomodate the environment
# !mkdir -p ./env
# Out:
# bin/micromamba

# %%
# Clone the KoVAE repository
# !git clone https://github.com/LeoneFabio/KoVAE.git
# Out:
# Cloning into 'KoVAE'...
# remote: Enumerating objects: 959, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (58/58), done.
# remote: Total 959 (delta 50), reused 67 (delta 31), pack-reused 865 (from 1)
# Receiving objects: 100% (959/959), 53.92 MiB | 24.07 MiB/s, done.
# Resolving deltas: 100% (313/313), done.

# %%
# !./bin/micromamba create -y -f ./KoVAE/environment.yml -p ./env
# Out:
# warning  libmamba Using existing empty folder as target prefix
# warning  libmamba 'repo.anaconda.com', a commercial channel hosted by Anaconda.com, is used.
#
# warning  libmamba Please make sure you understand Anaconda Terms of Services.
#
# warning  libmamba See: https://legal.anaconda.com/policies/en/
# [+] 0.0s
# [+] 0.1s
# pytorch/linux-64   ━━━━━━━━━━╸━━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# pytorch/noarch     ━━━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# pkgs/main/linux-64 ━╸━━━━━━━━━━━━━━━╸━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# pkgs/main/noarch   ━━━━━━━━━━━━━━━╸━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# pkgs/r/linux-64    ━━━━━━━━━━━╸━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s[+] 0.2s
# pkgs/main/linux-64 ━━━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/main/noarch   ━━━━━━━━━━━━━━━━━━━━━━━━━ 781.6kB / 781.6kB @   4.0MB/s  0.1s
# pkgs/r/linux-64    ━━━━━━━━━━━━━━╸━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# pkgs/r/noarch      ━━━━━━╸━━━━━━━━━━━━━━━╸━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0spkgs/main/noarch                                   781.6kB @   4.0MB/s  0.1s
# [+] 0.3s
# pkgs/main/linux-64   ━━━━━━━━━━━━━━━━━━━━━━━ 110.7kB /   8.3MB @ 375.7kB/s  0.2s
# conda-forge/linux-64 ━━╸━━━━━━━━━━━━━━━╸━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# conda-forge/noarch   ━━━━━━━━━━━━━━━╸━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# bioconda/linux-64    ━━━━━━━━━╸━━━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s
# bioconda/noarch      ━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0s[+] 0.4s
# pkgs/main/linux-64   ━━━━━━━╸━━━━━━━━━━━━━━━   3.1MB /   8.3MB @   7.9MB/s  0.3s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━━ 298.0kB /  46.9MB @   1.8MB/s  0.2s
# conda-forge/noarch   ━╸━━━━━━━━━━━━━━━━━━━━━   3.0MB /  22.2MB @  18.7MB/s  0.2s
# bioconda/linux-64    ━━━━━━━━━━━╸━━━━━━━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s
# bioconda/noarch      ━━━╸━━━━━━━━━━━━━━━╸━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.1s[+] 0.5s
# pkgs/main/linux-64   ━━━━━━━━━━━╸━━━━━━━━━━━   4.5MB /   8.3MB @  10.1MB/s  0.4s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━━━━━━   1.6MB /  46.9MB @   7.1MB/s  0.3s
# conda-forge/noarch   ━━━━━╸━━━━━━━━━━━━━━━━━   6.0MB /  22.2MB @  22.1MB/s  0.3s
# bioconda/linux-64    ━╸━━━━━━━━━━━━━━━━━━━━━ 563.5kB /   5.3MB @   2.6MB/s  0.2s
# bioconda/noarch      ━━╸━━━━━━━━━━━━━━━━━━━━ 719.8kB /   5.0MB @   3.3MB/s  0.2s[+] 0.6s
# pkgs/main/linux-64   ━━━━━━━━━━━━━━━━━━╸━━━━   7.0MB /   8.3MB @  12.4MB/s  0.5s
# conda-forge/linux-64 ╸━━━━━━━━━━━━━━━━━━━━━━   4.0MB /  46.9MB @  12.0MB/s  0.4s
# conda-forge/noarch   ━━━━━━╸━━━━━━━━━━━━━━━━   7.3MB /  22.2MB @  22.1MB/s  0.4s
# bioconda/linux-64    ━━━━━━━━━━━╸━━━━━━━━━━━   2.9MB /   5.3MB @   8.9MB/s  0.3s
# bioconda/noarch      ━━━━━╸━━━━━━━━━━━━━━━━━   1.5MB /   5.0MB @   5.5MB/s  0.3spkgs/main/linux-64                                   8.3MB @  13.0MB/s  0.6s
# [+] 0.7s
# conda-forge/linux-64 ━╸━━━━━━━━━━━━━━━━━━━━━   6.1MB /  46.9MB @  13.8MB/s  0.5s
# conda-forge/noarch   ━━━━━━━━╸━━━━━━━━━━━━━━   9.2MB /  22.2MB @  21.2MB/s  0.5s
# bioconda/linux-64    ━━━━━━━━━━━━━━━━━━━━╸━━   4.9MB /   5.3MB @  11.5MB/s  0.4s
# bioconda/noarch      ━━━━━━━━━━━━━━╸━━━━━━━━   3.4MB /   5.0MB @   9.1MB/s  0.4s
# nvidia/linux-64      ━╸━━━━━━━━━━━━━━━╸━━━━━   0.0 B /  ??.?MB @  ??.?MB/s  0.0sbioconda/linux-64                                    5.3MB @  11.5MB/s  0.4s
# bioconda/noarch                                      5.0MB @  11.0MB/s  0.4s
# nvidia/linux-64                                    264.6kB @ 216.2kB/s  0.1s
# nvidia/noarch                                       ??.?MB @  ??.?MB/s  0.1s
# [+] 0.8s
# conda-forge/linux-64 ━━━╸━━━━━━━━━━━━━━━━━━━   8.5MB /  46.9MB @  15.3MB/s  0.6s
# conda-forge/noarch   ━━━━━━━━━━━╸━━━━━━━━━━━  12.0MB /  22.2MB @  21.6MB/s  0.6s[+] 0.9s
# conda-forge/linux-64 ━━━━━╸━━━━━━━━━━━━━━━━━  13.3MB /  46.9MB @  20.1MB/s  0.7s
# conda-forge/noarch   ━━━━━━━━━━━━━━━━╸━━━━━━  16.8MB /  22.2MB @  25.4MB/s  0.7sconda-forge/noarch                                  22.2MB @  27.5MB/s  0.8s
# [+] 1.0s
# conda-forge/linux-64 ━━━━━━━━╸━━━━━━━━━━━━━━  18.9MB /  46.9MB @  24.5MB/s  0.8s[+] 1.1s
# conda-forge/linux-64 ━━━━━━━━━━━━━╸━━━━━━━━━  29.4MB /  46.9MB @  33.7MB/s  0.9s[+] 1.2s
# conda-forge/linux-64 ━━━━━━━━━━━━━━━━━━╸━━━━  39.4MB /  46.9MB @  40.5MB/s  1.0sconda-forge/linux-64                                46.9MB @  43.6MB/s  1.0s
#
#
# Transaction
#
#   Prefix: /home/dauin_user/fleone/env
#
#   Updating specs:
#
#    - _libgcc_mutex=0.1=conda_forge
#    - _openmp_mutex=4.5=2_gnu
#    - blas=1.0=mkl
#    - brotlipy=0.7.0=py39hb9d737c_1005
#    - bzip2=1.0.8=h7f98852_4
#    - ca-certificates=2023.5.7=hbcca054_0
#    - cffi=1.15.1=py39he91dace_3
#    - charset-normalizer=3.1.0=pyhd8ed1ab_0
#    - cloudpickle=2.2.1=pyhd8ed1ab_0
#    - colorama=0.4.6=pyhd8ed1ab_0
#    - cryptography=40.0.2=py39h079d5ae_0
#    - cuda-cudart=11.7.99=0
#    - cuda-cupti=11.7.101=0
#    - cuda-libraries=11.7.1=0
#    - cuda-nvrtc=11.7.99=0
#    - cuda-nvtx=11.7.91=0
#    - cuda-runtime=11.7.1=0
#    - cudatoolkit=11.8.0=h37601d7_11
#    - ffmpeg=4.3=hf484d3e_0
#    - filelock=3.12.0=pyhd8ed1ab_0
#    - freetype=2.12.1=hca18f0e_1
#    - future=0.18.3=pyhd8ed1ab_0
#    - gmp=6.2.1=h58526e2_0
#    - gmpy2=2.1.2=py39h376b7d2_1
#    - gnutls=3.6.13=h85f3911_1
#    - hyperopt=0.2.7=pyhd8ed1ab_0
#    - idna=3.4=pyhd8ed1ab_0
#    - intel-openmp=2021.4.0=h06a4308_3561
#    - jinja2=3.1.2=pyhd8ed1ab_1
#    - jpeg=9e=h0b41bf4_3
#    - lame=3.100=h166bdaf_1003
#    - lcms2=2.15=hfd0df8a_0
#    - ld_impl_linux-64=2.40=h41732ed_0
#    - lerc=4.0.0=h27087fc_0
#    - libcublas=11.10.3.66=0
#    - libcufft=10.7.2.124=h4fbf590_0
#    - libcufile=1.6.1.9=0
#    - libcurand=10.3.2.106=0
#    - libcusolver=11.4.0.1=0
#    - libcusparse=11.7.4.91=0
#    - libdeflate=1.17=h0b41bf4_0
#    - libffi=3.4.2=h7f98852_5
#    - libgcc-ng=12.2.0=h65d4601_19
#    - libgfortran-ng=13.1.0=h69a702a_0
#    - libgfortran5=13.1.0=h15d22d2_0
#    - libgomp=12.2.0=h65d4601_19
#    - libiconv=1.17=h166bdaf_0
#    - libnpp=11.7.4.75=0
#    - libnsl=2.0.0=h7f98852_0
#    - libnvjpeg=11.8.0.2=0
#    - libpng=1.6.39=h753d276_0
#    - libsqlite=3.40.0=h753d276_0
#    - libstdcxx-ng=12.2.0=h46fd767_19
#    - libtiff=4.5.0=h6adf6a1_2
#    - libuuid=2.38.1=h0b41bf4_0
#    - libwebp-base=1.3.0=h0b41bf4_0
#    - libxcb=1.13=h7f98852_1004
#    - libzlib=1.2.13=h166bdaf_4
#    - markupsafe=2.1.2=py39h72bdee0_0
#    - mkl=2021.4.0=h06a4308_640
#    - mkl-service=2.4.0=py39h7e14d7c_0
#    - mkl_fft=1.3.1=py39h0c7bc48_1
#    - mkl_random=1.2.2=py39hde0f152_0
#    - mpc=1.3.1=hfe3b2da_0
#    - mpfr=4.2.0=hb012696_0
#    - mpmath=1.3.0=pyhd8ed1ab_0
#    - ncurses=6.3=h27087fc_1
#    - nettle=3.6=he412f7d_0
#    - networkx=3.1=pyhd8ed1ab_0
#    - numpy=1.23.5=py39h14f4228_0
#    - numpy-base=1.23.5=py39h31eccc5_0
#    - openh264=2.1.1=h780b84a_0
#    - openjpeg=2.5.0=hfec8fc6_2
#    - openssl=3.1.1=hd590300_1
#    - pip=23.1=pyhd8ed1ab_0
#    - pthread-stubs=0.4=h36c2ea0_1001
#    - py4j=0.10.9.7=pyhd8ed1ab_0
#    - pycparser=2.21=pyhd8ed1ab_0
#    - pyopenssl=23.1.1=pyhd8ed1ab_0
#    - pysocks=1.7.1=pyha2e5f31_6
#    - python=3.9.16=h2782a2a_0_cpython
#    - python_abi=3.9=3_cp39
#    - pytorch[version="=2.0.0",build="^py3.9_cuda11.7_cudnn8.5.0_0$"]
#    - pytorch-cuda=11.7=h778d358_3
#    - pytorch-mutex=1.0=cuda
#    - readline=8.2=h8228510_1
#    - requests=2.28.2=pyhd8ed1ab_1
#    - setuptools=67.6.1=pyhd8ed1ab_0
#    - six=1.16.0=pyh6c4a22f_0
#    - sympy=1.11.1=pypyh9d50eac_103
#    - tk=8.6.12=h27826a3_0
#    - torchaudio=2.0.0=py39_cu117
#    - torchtriton=2.0.0=py39
#    - torchvision=0.15.0=py39_cu117
#    - tqdm=4.65.0=pyhd8ed1ab_1
#    - typing_extensions=4.5.0=pyha770c72_0
#    - urllib3=1.26.15=pyhd8ed1ab_0
#    - wheel=0.40.0=pyhd8ed1ab_0
#    - xorg-libxau=1.0.9=h7f98852_0
#    - xorg-libxdmcp=1.1.3=h7f98852_0
#    - xz=5.2.6=h166bdaf_0
#    - zlib=1.2.13=h166bdaf_4
#    - zstd=1.5.2=h3eb15da_6
#    - pip
#
#
#   Package                  Version  Build                        Channel           Size
# ─────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex              0.1  conda_forge                  conda-forge     Cached
#   + _openmp_mutex              4.5  2_gnu                        conda-forge     Cached
#   + blas                       1.0  mkl                          pkgs/main       Cached
#   + brotlipy                 0.7.0  py39hb9d737c_1005            conda-forge     Cached
#   + bzip2                    1.0.8  h7f98852_4                   conda-forge     Cached
#   + ca-certificates       2023.5.7  hbcca054_0                   conda-forge     Cached
#   + certifi               2025.8.3  py39h06a4308_0               pkgs/main       Cached
#   + cffi                    1.15.1  py39he91dace_3               conda-forge     Cached
#   + charset-normalizer       3.1.0  pyhd8ed1ab_0                 conda-forge     Cached
#   + cloudpickle              2.2.1  pyhd8ed1ab_0                 conda-forge     Cached
#   + colorama                 0.4.6  pyhd8ed1ab_0                 conda-forge     Cached
#   + cryptography            40.0.2  py39h079d5ae_0               conda-forge     Cached
#   + cuda-cudart            11.7.99  0                            nvidia          Cached
#   + cuda-cupti            11.7.101  0                            nvidia          Cached
#   + cuda-libraries          11.7.1  0                            nvidia          Cached
#   + cuda-nvrtc             11.7.99  0                            nvidia          Cached
#   + cuda-nvtx              11.7.91  0                            nvidia          Cached
#   + cuda-runtime            11.7.1  0                            nvidia          Cached
#   + cudatoolkit             11.8.0  h37601d7_11                  conda-forge     Cached
#   + ffmpeg                     4.3  hf484d3e_0                   pytorch         Cached
#   + filelock                3.12.0  pyhd8ed1ab_0                 conda-forge     Cached
#   + freetype                2.12.1  hca18f0e_1                   conda-forge     Cached
#   + future                  0.18.3  pyhd8ed1ab_0                 conda-forge     Cached
#   + gmp                      6.2.1  h58526e2_0                   conda-forge     Cached
#   + gmpy2                    2.1.2  py39h376b7d2_1               conda-forge     Cached
#   + gnutls                  3.6.13  h85f3911_1                   conda-forge     Cached
#   + hyperopt                 0.2.7  pyhd8ed1ab_0                 conda-forge     Cached
#   + idna                       3.4  pyhd8ed1ab_0                 conda-forge     Cached
#   + intel-openmp          2021.4.0  h06a4308_3561                pkgs/main       Cached
#   + jinja2                   3.1.2  pyhd8ed1ab_1                 conda-forge     Cached
#   + jpeg                        9e  h0b41bf4_3                   conda-forge     Cached
#   + lame                     3.100  h166bdaf_1003                conda-forge     Cached
#   + lcms2                     2.15  hfd0df8a_0                   conda-forge     Cached
#   + ld_impl_linux-64          2.40  h41732ed_0                   conda-forge     Cached
#   + lerc                     4.0.0  h27087fc_0                   conda-forge     Cached
#   + libcublas           11.10.3.66  0                            nvidia          Cached
#   + libcufft            10.7.2.124  h4fbf590_0                   nvidia          Cached
#   + libcufile              1.6.1.9  0                            nvidia          Cached
#   + libcurand           10.3.2.106  0                            nvidia          Cached
#   + libcusolver           11.4.0.1  0                            nvidia          Cached
#   + libcusparse          11.7.4.91  0                            nvidia          Cached
#   + libdeflate                1.17  h0b41bf4_0                   conda-forge     Cached
#   + libffi                   3.4.2  h7f98852_5                   conda-forge     Cached
#   + libgcc-ng               12.2.0  h65d4601_19                  conda-forge     Cached
#   + libgfortran-ng          13.1.0  h69a702a_0                   conda-forge     Cached
#   + libgfortran5            13.1.0  h15d22d2_0                   conda-forge     Cached
#   + libgomp                 12.2.0  h65d4601_19                  conda-forge     Cached
#   + libiconv                  1.17  h166bdaf_0                   conda-forge     Cached
#   + libnpp               11.7.4.75  0                            nvidia          Cached
#   + libnsl                   2.0.0  h7f98852_0                   conda-forge     Cached
#   + libnvjpeg             11.8.0.2  0                            nvidia          Cached
#   + libpng                  1.6.39  h753d276_0                   conda-forge     Cached
#   + libsqlite               3.40.0  h753d276_0                   conda-forge     Cached
#   + libstdcxx-ng            12.2.0  h46fd767_19                  conda-forge     Cached
#   + libtiff                  4.5.0  h6adf6a1_2                   conda-forge     Cached
#   + libuuid                 2.38.1  h0b41bf4_0                   conda-forge     Cached
#   + libwebp-base             1.3.0  h0b41bf4_0                   conda-forge     Cached
#   + libxcb                    1.13  h7f98852_1004                conda-forge     Cached
#   + libzlib                 1.2.13  h166bdaf_4                   conda-forge     Cached
#   + markupsafe               2.1.2  py39h72bdee0_0               conda-forge     Cached
#   + mkl                   2021.4.0  h06a4308_640                 pkgs/main       Cached
#   + mkl-service              2.4.0  py39h7e14d7c_0               conda-forge     Cached
#   + mkl_fft                  1.3.1  py39h0c7bc48_1               conda-forge     Cached
#   + mkl_random               1.2.2  py39hde0f152_0               conda-forge     Cached
#   + mpc                      1.3.1  hfe3b2da_0                   conda-forge     Cached
#   + mpfr                     4.2.0  hb012696_0                   conda-forge     Cached
#   + mpmath                   1.3.0  pyhd8ed1ab_0                 conda-forge     Cached
#   + ncurses                    6.3  h27087fc_1                   conda-forge     Cached
#   + nettle                     3.6  he412f7d_0                   conda-forge     Cached
#   + networkx                   3.1  pyhd8ed1ab_0                 conda-forge     Cached
#   + numpy                   1.23.5  py39h14f4228_0               pkgs/main       Cached
#   + numpy-base              1.23.5  py39h31eccc5_0               pkgs/main       Cached
#   + olefile                   0.46  pyhd3eb1b0_0                 pkgs/main       Cached
#   + openh264                 2.1.1  h780b84a_0                   conda-forge     Cached
#   + openjpeg                 2.5.0  hfec8fc6_2                   conda-forge     Cached
#   + openssl                  3.1.1  hd590300_1                   conda-forge     Cached
#   + packaging                 25.0  py39h06a4308_0               pkgs/main       Cached
#   + pillow                   8.2.0  py39he98fc37_0               pkgs/main       Cached
#   + pip                     23.1.2  pyhd8ed1ab_0                 conda-forge     Cached
#   + platformdirs             4.3.7  py39h06a4308_0               pkgs/main       Cached
#   + pooch                    1.8.2  py39h06a4308_0               pkgs/main       Cached
#   + pthread-stubs              0.4  h36c2ea0_1001                conda-forge     Cached
#   + py4j                  0.10.9.7  pyhd8ed1ab_0                 conda-forge     Cached
#   + pycparser                 2.21  pyhd8ed1ab_0                 conda-forge     Cached
#   + pyopenssl               23.1.1  pyhd8ed1ab_0                 conda-forge     Cached
#   + pysocks                  1.7.1  pyha2e5f31_6                 conda-forge     Cached
#   + python                  3.9.16  h2782a2a_0_cpython           conda-forge     Cached
#   + python_abi                 3.9  3_cp39                       conda-forge     Cached
#   + pytorch                  2.0.0  py3.9_cuda11.7_cudnn8.5.0_0  pytorch         Cached
#   + pytorch-cuda              11.7  h778d358_3                   pytorch         Cached
#   + pytorch-mutex              1.0  cuda                         pytorch         Cached
#   + readline                   8.2  h8228510_1                   conda-forge     Cached
#   + requests                2.28.2  pyhd8ed1ab_1                 conda-forge     Cached
#   + scipy                   1.10.1  py39h14f4228_0               pkgs/main       Cached
#   + setuptools              67.6.1  pyhd8ed1ab_0                 conda-forge     Cached
#   + six                     1.16.0  pyh6c4a22f_0                 conda-forge     Cached
#   + sympy                   1.11.1  pypyh9d50eac_103             conda-forge     Cached
#   + tk                      8.6.12  h27826a3_0                   conda-forge     Cached
#   + torchaudio               2.0.0  py39_cu117                   pytorch         Cached
#   + torchtriton              2.0.0  py39                         pytorch         Cached
#   + torchvision             0.15.0  py39_cu117                   pytorch         Cached
#   + tqdm                    4.65.0  pyhd8ed1ab_1                 conda-forge     Cached
#   + typing_extensions        4.5.0  pyha770c72_0                 conda-forge     Cached
#   + tzdata                   2025b  h04d1e81_0                   pkgs/main       Cached
#   + urllib3                1.26.15  pyhd8ed1ab_0                 conda-forge     Cached
#   + wheel                   0.40.0  pyhd8ed1ab_0                 conda-forge     Cached
#   + xorg-libxau              1.0.9  h7f98852_0                   conda-forge     Cached
#   + xorg-libxdmcp            1.1.3  h7f98852_0                   conda-forge     Cached
#   + xz                       5.2.6  h166bdaf_0                   conda-forge     Cached
#   + zlib                    1.2.13  h166bdaf_4                   conda-forge     Cached
#   + zstd                     1.5.2  h3eb15da_6                   conda-forge     Cached
#
#   Summary:
#
#   Install: 111 packages
#
#   Total download: 0 B
#
# ─────────────────────────────────────────────────────────────────────────────────────────
#
#
#
# Transaction starting
# [+] 0.0s
# Linking _libgcc_mutex-0.1-conda_forge
# Linking ca-certificates-2023.5.7-hbcca054_0
# Linking ld_impl_linux-64-2.40-h41732ed_0
# Linking libgfortran5-13.1.0-h15d22d2_0
# Linking libstdcxx-ng-12.2.0-h46fd767_19
# Linking python_abi-3.9-3_cp39
# Linking libgomp-12.2.0-h65d4601_19
# Linking libgfortran-ng-13.1.0-h69a702a_0
# Linking _openmp_mutex-4.5-2_gnu
# Linking libgcc-ng-12.2.0-h65d4601_19
# Linking xz-5.2.6-h166bdaf_0
# Linking xorg-libxdmcp-1.1.3-h7f98852_0
# Linking xorg-libxau-1.0.9-h7f98852_0
# Linking pthread-stubs-0.4-h36c2ea0_1001
# Linking openssl-3.1.1-hd590300_1
# Linking nettle-3.6-he412f7d_0
# Linking ncurses-6.3-h27087fc_1
# Linking libzlib-1.2.13-h166bdaf_4
# Linking libwebp-base-1.3.0-h0b41bf4_0
# Linking libuuid-2.38.1-h0b41bf4_0
# Linking libnsl-2.0.0-h7f98852_0
# Linking libiconv-1.17-h166bdaf_0
# Linking libffi-3.4.2-h7f98852_5
# Linking libdeflate-1.17-h0b41bf4_0
# Linking lerc-4.0.0-h27087fc_0
# Linking lame-3.100-h166bdaf_1003
# Linking jpeg-9e-h0b41bf4_3
# Linking gmp-6.2.1-h58526e2_0
# Linking cudatoolkit-11.8.0-h37601d7_11
# By downloading and using the CUDA Toolkit conda packages, you accept the terms and conditions of the CUDA End User License Agreement (EULA): https://docs.nvidia.com/cuda/eula/index.html
#
# Linking bzip2-1.0.8-h7f98852_4
# Linking libxcb-1.13-h7f98852_1004
# Linking gnutls-3.6.13-h85f3911_1
# Linking readline-8.2-h8228510_1
# Linking zstd-1.5.2-h3eb15da_6
# Linking zlib-1.2.13-h166bdaf_4
# Linking tk-8.6.12-h27826a3_0
# Linking libsqlite-3.40.0-h753d276_0
# Linking libpng-1.6.39-h753d276_0
# Linking mpfr-4.2.0-hb012696_0
# Linking libtiff-4.5.0-h6adf6a1_2
# Linking openh264-2.1.1-h780b84a_0
# Linking freetype-2.12.1-hca18f0e_1
# Linking mpc-1.3.1-hfe3b2da_0
# Linking openjpeg-2.5.0-hfec8fc6_2
# Linking lcms2-2.15-hfd0df8a_0
# Linking cuda-cudart-11.7.99-0
# warning  libmamba [cuda-cudart-11.7.99-0] The following files were already present in the environment:
#     - lib/libcudart.so.11.0
# Linking cuda-cupti-11.7.101-0
# warning  libmamba [cuda-cupti-11.7.101-0] The following files were already present in the environment:
#     - lib/libcupti.so
# Linking cuda-nvrtc-11.7.99-0
# warning  libmamba [cuda-nvrtc-11.7.99-0] The following files were already present in the environment:
#     - lib/libnvrtc.so.11.2
# Linking cuda-nvtx-11.7.91-0
# warning  libmamba [cuda-nvtx-11.7.91-0] The following files were already present in the environment:
#     - LICENSE
#     - lib/libnvToolsExt.so
#     - lib/libnvToolsExt.so.1
#     - lib/libnvToolsExt.so.1.0.0
# Linking libcublas-11.10.3.66-0
# warning  libmamba [libcublas-11.10.3.66-0] The following files were already present in the environment:
#     - lib/libcublas.so.11
#     - lib/libcublasLt.so.11
#     - lib/libnvblas.so.11
# Linking libcufft-10.7.2.124-h4fbf590_0
# warning  libmamba [libcufft-10.7.2.124-h4fbf590_0] The following files were already present in the environment:
#     - lib/libcufft.so.10
#     - lib/libcufftw.so.10
# Linking libcufile-1.6.1.9-0
# Linking libcurand-10.3.2.106-0
# warning  libmamba [libcurand-10.3.2.106-0] The following files were already present in the environment:
#     - lib/libcurand.so.10
# Linking libcusolver-11.4.0.1-0
# warning  libmamba [libcusolver-11.4.0.1-0] The following files were already present in the environment:
#     - lib/libcusolver.so.11
#     - lib/libcusolverMg.so.11
# Linking libcusparse-11.7.4.91-0
# warning  libmamba [libcusparse-11.7.4.91-0] The following files were already present in the environment:
#     - lib/libcusparse.so.11
# Linking libnpp-11.7.4.75-0
# warning  libmamba [libnpp-11.7.4.75-0] The following files were already present in the environment:
#     - lib/libnppc.so.11
#     - lib/libnppial.so.11
#     - lib/libnppicc.so.11
#     - lib/libnppidei.so.11
#     - lib/libnppif.so.11
#     - lib/libnppig.so.11
#     - lib/libnppim.so.11
#     - lib/libnppist.so.11
#     - lib/libnppisu.so.11
#     - lib/libnppitc.so.11
#     - lib/libnpps.so.11
# Linking libnvjpeg-11.8.0.2-0
# warning  libmamba [libnvjpeg-11.8.0.2-0] The following files were already present in the environment:
#     - lib/libnvjpeg.so.11
# Linking cuda-libraries-11.7.1-0
# Linking cuda-runtime-11.7.1-0
# Linking intel-openmp-2021.4.0-h06a4308_3561
# Linking blas-1.0-mkl
# Linking mkl-2021.4.0-h06a4308_640
# Linking pytorch-mutex-1.0-cuda
# Linking tzdata-2025b-h04d1e81_0
# Linking ffmpeg-4.3-hf484d3e_0
# Linking pytorch-cuda-11.7-h778d358_3
# Linking python-3.9.16-h2782a2a_0_cpython
# Linking wheel-0.40.0-pyhd8ed1ab_0
# Linking setuptools-67.6.1-pyhd8ed1ab_0
# Linking pip-23.1.2-pyhd8ed1ab_0
# Linking typing_extensions-4.5.0-pyha770c72_0
# Linking six-1.16.0-pyh6c4a22f_0
# Linking pysocks-1.7.1-pyha2e5f31_6
# Linking pycparser-2.21-pyhd8ed1ab_0
# Linking py4j-0.10.9.7-pyhd8ed1ab_0
# Linking networkx-3.1-pyhd8ed1ab_0
# Linking mpmath-1.3.0-pyhd8ed1ab_0
# Linking idna-3.4-pyhd8ed1ab_0
# Linking future-0.18.3-pyhd8ed1ab_0
# Linking filelock-3.12.0-pyhd8ed1ab_0
# Linking colorama-0.4.6-pyhd8ed1ab_0
# Linking cloudpickle-2.2.1-pyhd8ed1ab_0
# Linking charset-normalizer-3.1.0-pyhd8ed1ab_0
# Linking tqdm-4.65.0-pyhd8ed1ab_1
# Linking olefile-0.46-pyhd3eb1b0_0
# Linking platformdirs-4.3.7-py39h06a4308_0
# Linking packaging-25.0-py39h06a4308_0
# Linking certifi-2025.8.3-py39h06a4308_0
# Linking pillow-8.2.0-py39he98fc37_0
# Linking markupsafe-2.1.2-py39h72bdee0_0
# Linking gmpy2-2.1.2-py39h376b7d2_1
# Linking mkl-service-2.4.0-py39h7e14d7c_0
# Linking cffi-1.15.1-py39he91dace_3
# Linking cryptography-40.0.2-py39h079d5ae_0
# Linking brotlipy-0.7.0-py39hb9d737c_1005
# Linking jinja2-3.1.2-pyhd8ed1ab_1
# Linking sympy-1.11.1-pypyh9d50eac_103
# Linking pyopenssl-23.1.1-pyhd8ed1ab_0
# Linking urllib3-1.26.15-pyhd8ed1ab_0
# Linking requests-2.28.2-pyhd8ed1ab_1
# Linking numpy-base-1.23.5-py39h31eccc5_0
# Linking pooch-1.8.2-py39h06a4308_0
# Linking numpy-1.23.5-py39h14f4228_0
# Linking pytorch-2.0.0-py3.9_cuda11.7_cudnn8.5.0_0
# Linking torchtriton-2.0.0-py39
# Linking mkl_fft-1.3.1-py39h0c7bc48_1
# Linking mkl_random-1.2.2-py39hde0f152_0
# Linking scipy-1.10.1-py39h14f4228_0
# Linking torchvision-0.15.0-py39_cu117
# Linking torchaudio-2.0.0-py39_cu117
# Linking hyperopt-0.2.7-pyhd8ed1ab_0
#
# Transaction finished
#
#
# To activate this environment, use:
#
#     micromamba activate /home/dauin_user/fleone/env
#
# Or to execute a single command in this environment, use:
#
#     micromamba run -p /home/dauin_user/fleone/env mycommand
#
# warning  libmamba You are using 'pip' as an additional package manager.
#     Be aware that packages installed with 'pip' are managed independently from 'conda-forge' channel.
#
# Installing pip packages: absl-py==1.4.0, argparse==1.4.0, arrow==1.2.3, astunparse==1.6.3, attrs==23.1.0, boto3==1.26.149, botocore==1.29.149, bravado==11.0.3, bravado-core==5.17.1, cachetools==5.3.0, certifi==2022.12.7, click==8.1.3, contourpy==1.0.7, cycler==0.11.0, flatbuffers==23.3.3, fonttools==4.39.3, fqdn==1.5.1, gast==0.4.0, gitdb==4.0.10, gitpython==3.1.31, google-auth==2.17.3, google-auth-oauthlib==1.0.0, google-pasta==0.2.0, grpcio==1.53.0, h5py==3.8.0, importlib-metadata==6.4.1, importlib-resources==5.12.0, isoduration==20.11.0, jax==0.4.8, jmespath==1.0.1, joblib==1.2.0, jsonpointer==2.3, jsonref==1.1.0, jsonschema==4.17.3, keras==2.12.0, kiwisolver==1.4.4, libclang==16.0.0, markdown==3.4.3, matplotlib==3.7.1, ml-dtypes==0.1.0, monotonic==1.6, msgpack==1.0.5, neptune==1.2.0, nvidia-cublas-cu11==11.11.3.6, nvidia-cudnn-cu11==8.6.0.163, oauthlib==3.2.2, opt-einsum==3.3.0, packaging==23.1, pandas==2.0.2, pillow==9.5.0, protobuf==4.22.3, psutil==5.9.5, pyasn1==0.4.8, pyasn1-modules==0.2.8, pyjwt==2.7.0, pyparsing==3.0.9, pyrsistent==0.19.3, python-dateutil==2.8.2, pytz==2023.3, pyyaml==6.0, requests-oauthlib==1.3.1, rfc3339-validator==0.1.4, rfc3987==1.3.8, rsa==4.9, s3transfer==0.6.1, scikit-learn==1.2.2, scipy==1.10.1, simplejson==3.19.1, smmap==5.0.0, swagger-spec-validator==3.0.3, tensorboard==2.12.2, tensorboard-data-server==0.7.0, tensorboard-plugin-wit==1.8.1, tensorflow==2.12.0, tensorflow-estimator==2.12.0, tensorflow-io-gcs-filesystem==0.32.0, termcolor==2.2.0, threadpoolctl==3.1.0, torchdiffeq==0.2.3, tzdata==2023.3, uri-template==1.2.0, webcolors==1.13, websocket-client==1.5.2, werkzeug==2.2.3, wrapt==1.14.1, zipp==3.15.0

# %%
# !./env/bin/python -m pip install seaborn
# !./env/bin/python -m pip install matplotlib-inline
# !./env/bin/python -m pip install ipython
# Out:
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in ./env/lib/python3.9/site-packages (from seaborn) (1.23.5)
# Requirement already satisfied: pandas>=1.2 in ./env/lib/python3.9/site-packages (from seaborn) (2.0.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in ./env/lib/python3.9/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in ./env/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in ./env/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./env/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./env/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in ./env/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in ./env/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./env/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in ./env/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./env/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (5.12.0)
# Requirement already satisfied: pytz>=2020.1 in ./env/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: tzdata>=2022.1 in ./env/lib/python3.9/site-packages (from pandas>=1.2->seaborn) (2023.3)
# Requirement already satisfied: zipp>=3.1.0 in ./env/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.4->seaborn) (3.15.0)
# Requirement already satisfied: six>=1.5 in ./env/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# Collecting matplotlib-inline
#   Using cached matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Collecting traitlets (from matplotlib-inline)
#   Using cached traitlets-5.14.3-py3-none-any.whl (85 kB)
# Installing collected packages: traitlets, matplotlib-inline
# Successfully installed matplotlib-inline-0.1.7 traitlets-5.14.3
# Collecting ipython
#   Using cached ipython-8.18.1-py3-none-any.whl (808 kB)
# Collecting decorator (from ipython)
#   Using cached decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Collecting jedi>=0.16 (from ipython)
#   Using cached jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
# Requirement already satisfied: matplotlib-inline in ./env/lib/python3.9/site-packages (from ipython) (0.1.7)
# Collecting prompt-toolkit<3.1.0,>=3.0.41 (from ipython)
#   Using cached prompt_toolkit-3.0.52-py3-none-any.whl (391 kB)
# Collecting pygments>=2.4.0 (from ipython)
#   Using cached pygments-2.19.2-py3-none-any.whl (1.2 MB)
# Collecting stack-data (from ipython)
#   Using cached stack_data-0.6.3-py3-none-any.whl (24 kB)
# Requirement already satisfied: traitlets>=5 in ./env/lib/python3.9/site-packages (from ipython) (5.14.3)
# Requirement already satisfied: typing-extensions in ./env/lib/python3.9/site-packages (from ipython) (4.5.0)
# Collecting exceptiongroup (from ipython)
#   Using cached exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Collecting pexpect>4.3 (from ipython)
#   Using cached pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython)
#   Using cached parso-0.8.5-py2.py3-none-any.whl (106 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython)
#   Using cached ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Collecting wcwidth (from prompt-toolkit<3.1.0,>=3.0.41->ipython)
#   Using cached wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Collecting typing-extensions (from ipython)
#   Using cached typing_extensions-4.15.0-py3-none-any.whl (44 kB)
# Collecting executing>=1.2.0 (from stack-data->ipython)
#   Using cached executing-2.2.1-py2.py3-none-any.whl (28 kB)
# Collecting asttokens>=2.1.0 (from stack-data->ipython)
#   Using cached asttokens-3.0.0-py3-none-any.whl (26 kB)
# Collecting pure-eval (from stack-data->ipython)
#   Using cached pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Installing collected packages: wcwidth, pure-eval, ptyprocess, typing-extensions, pygments, prompt-toolkit, pexpect, parso, executing, decorator, asttokens, stack-data, jedi, exceptiongroup, ipython
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# triton 2.0.0 requires cmake, which is not installed.
# triton 2.0.0 requires lit, which is not installed.
# Successfully installed asttokens-3.0.0 decorator-5.2.1 exceptiongroup-1.3.0 executing-2.2.1 ipython-8.18.1 jedi-0.19.2 parso-0.8.5 pexpect-4.9.0 prompt-toolkit-3.0.52 ptyprocess-0.7.0 pure-eval-0.2.3 pygments-2.19.2 stack-data-0.6.3 typing-extensions-4.15.0 wcwidth-0.2.13

# %%
# %cd ./KoVAE
# Out:
# /home/dauin_user/fleone/KoVAE

# %%
'''
# IF IT'S NOT POSSIBLE TO CREATE A MAMBA ENVIRONMENT


# Clone the KoVAE repository
# !git clone https://github.com/LeoneFabio/KoVAE.git

# %cd ./KoVAE


# Install system dependencies
# !apt-get update
# !apt-get install -y ffmpeg bzip2 libomp-dev

# The repository requires a specific version of PyTorch with CUDA support (CUDA 11.7)
# Install PyTorch with CUDA support (CUDA 11.7)
# !pip install torch==2.0.0+cu117 torchvision==0.15.0+cu117 torchaudio==2.0.0+cu117 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install --upgrade seaborn

# Install necessary Python packages
# !pip install absl-py==1.4.0 boto3==1.26.149 pandas==2.0.2 scikit-learn==1.2.2
# !pip install tensorflow==2.12.0 tensorboard==2.12.2
# !pip install hyperopt==0.2.7 joblib==1.2.0 matplotlib==3.7.1
# !pip install nvidia-cublas-cu11==11.11.3.6 nvidia-cudnn-cu11==8.6.0.163
# !pip install torchdiffeq==0.2.3
# !pip install neptune-client

'''

# %%
##################### TO RUN ONLY AFTER A WRONG EXECUTION OF THE NEXT CELL ################
# !rm -rf datasets/EV0.3/ datasets/stock0.3/ Generated_data/ Output_info/ visualizations/

# %%
## Main run

# !../env/bin/python run_irregular.py --dataset EV --w_rec 1. --w_kl 0.005 --w_pred_prior .02 --inp_dim 5 --epochs 1200 --seq_len 10 --seed 10
# Out:
# 2025-11-19 17:38:20.702379: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-11-19 17:38:21.864526: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/dauin_user/fleone/KoVAE/run_irregular.py:5: NeptuneDeprecationWarning: You're importing the Neptune client library via the deprecated `neptune.new` module, which will be removed in a future release. Import directly from `neptune` instead.
#   import neptune.new as neptune
# Preprocessing complete. Output saved to ./Output_info/EV_processed.csv
# ['event', 'charge_mode', 'duration_minutes', 'km_driven', 'charge']
# /home/dauin_user/fleone/KoVAE/utils/utils_data.py:555: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /opt/conda/conda-bld/pytorch_1678402374358/work/torch/csrc/utils/tensor_new.cpp:245.)
#   self.original_sample = torch.tensor(self.original_sample)
# 2025-11-19 17:38:46,638 - INFO - EV dataset is ready.
# 2025-11-19 17:38:46,648 - INFO - Namespace(epochs=1200, lr=0.001, weight_decay=5e-05, seed=10, pinv_solver=False, neptune='debug', tag='sine, alpha_beta_sens', dataset='EV', batch_size=64, seq_len=10, inp_dim=5, missing_value=0.3, batch_norm=True, num_layers=3, z_dim=16, hidden_dim=20, num_steps=1, w_rec=1.0, w_kl=0.005, w_pred_prior=0.02, event=None, charge_mode=None, device=device(type='cpu'), log_dir='./logs/EV/KOVAEIrreg-1200_bs=64-rnn_size=20-z_dim=16-lr=0.001-n_layers=3=-weight:kl=0.005-pred=0.02-w_decay=5e-05-seed=10')
# 2025-11-19 17:38:46,648 - INFO - number of model parameters: 34381
# number of model parameters: 34381
# 2025-11-19 17:38:46,648 - INFO - Starting training loop at step 0.
# 2025-11-19 17:38:46,649 - INFO - Epoch 1/1200 | w_rec=1.0, w_kl=0.0000000, w_pred_prior=0.0200
# 2025-11-19 17:38:50,598 - INFO - Epoch 1, TRAIN: total=1.339e-01, 	rec=1.335e-01 (weighted=1.335e-01), 	kl=2.370e+00 (weighted=0.000e+00), 	pred_prior=1.878e-02 (weighted=3.755e-04),
# /home/dauin_user/fleone/KoVAE/run_irregular.py:236: RuntimeWarning: invalid value encountered in double_scalars
#   unweighted_kl_losses.append(weighted_losses['kl'] / current_w_kl)
# /home/dauin_user/fleone/KoVAE/run_irregular.py:240: RuntimeWarning: invalid value encountered in double_scalars
#   unweighted_total_losses.append(weighted_losses['rec'] / args.w_rec + weighted_losses['kl'] / current_w_kl + weighted_losses['pred_prior'] / args.w_pred_prior)
# 2025-11-19 17:38:50,598 - INFO - EV Penalties: {}
# 2025-11-19 17:38:50,598 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:38:50,598 - INFO - ##############################
# 2025-11-19 17:38:50,598 - INFO - Epoch 2/1200 | w_rec=1.0, w_kl=0.0000000, w_pred_prior=0.0200
# 2025-11-19 17:38:54,671 - INFO - Epoch 2, TRAIN: total=7.850e-02, 	rec=7.826e-02 (weighted=7.826e-02), 	kl=5.459e+00 (weighted=8.334e-08), 	pred_prior=1.202e-02 (weighted=2.405e-04),
# 2025-11-19 17:38:54,671 - INFO - EV Penalties: {}
# 2025-11-19 17:38:54,671 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:38:54,671 - INFO - ##############################
# 2025-11-19 17:38:54,671 - INFO - Epoch 3/1200 | w_rec=1.0, w_kl=0.0000001, w_pred_prior=0.0200
# 2025-11-19 17:38:58,587 - INFO - Epoch 3, TRAIN: total=6.750e-02, 	rec=6.737e-02 (weighted=6.737e-02), 	kl=7.574e+00 (weighted=4.625e-07), 	pred_prior=6.418e-03 (weighted=1.284e-04),
# 2025-11-19 17:38:58,587 - INFO - EV Penalties: {}
# 2025-11-19 17:38:58,587 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:38:58,587 - INFO - ##############################
# 2025-11-19 17:38:58,587 - INFO - Epoch 4/1200 | w_rec=1.0, w_kl=0.0000001, w_pred_prior=0.0200
# 2025-11-19 17:39:02,473 - INFO - Epoch 4, TRAIN: total=3.568e-02, 	rec=3.557e-02 (weighted=3.557e-02), 	kl=1.367e+01 (weighted=1.878e-06), 	pred_prior=5.045e-03 (weighted=1.009e-04),
# 2025-11-19 17:39:02,473 - INFO - EV Penalties: {}
# 2025-11-19 17:39:02,473 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:39:02,474 - INFO - ##############################
# 2025-11-19 17:39:02,474 - INFO - Epoch 5/1200 | w_rec=1.0, w_kl=0.0000002, w_pred_prior=0.0200
# 2025-11-19 17:39:06,368 - INFO - Epoch 5, TRAIN: total=1.522e-02, 	rec=1.512e-02 (weighted=1.512e-02), 	kl=1.693e+01 (weighted=4.134e-06), 	pred_prior=4.662e-03 (weighted=9.324e-05),
# 2025-11-19 17:39:06,368 - INFO - EV Penalties: {}
# 2025-11-19 17:39:06,368 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:39:06,368 - INFO - ##############################
# 2025-11-19 17:39:06,368 - INFO - Epoch 6/1200 | w_rec=1.0, w_kl=0.0000004, w_pred_prior=0.0200
# 2025-11-19 17:39:10,387 - INFO - Epoch 6, TRAIN: total=1.285e-02, 	rec=1.276e-02 (weighted=1.276e-02), 	kl=1.661e+01 (weighted=6.337e-06), 	pred_prior=4.323e-03 (weighted=8.646e-05),
# 2025-11-19 17:39:10,387 - INFO - EV Penalties: {}
# 2025-11-19 17:39:10,387 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:39:10,387 - INFO - ##############################
# 2025-11-19 17:39:10,387 - INFO - Epoch 7/1200 | w_rec=1.0, w_kl=0.0000005, w_pred_prior=0.0200
# 2025-11-19 17:39:14,307 - INFO - Epoch 7, TRAIN: total=1.230e-02, 	rec=1.221e-02 (weighted=1.221e-02), 	kl=1.633e+01 (weighted=8.975e-06), 	pred_prior=4.163e-03 (weighted=8.327e-05),
# 2025-11-19 17:39:14,308 - INFO - EV Penalties: {}
# 2025-11-19 17:39:14,308 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:39:14,308 - INFO - ##############################
# 2025-11-19 17:39:14,308 - INFO - Epoch 8/1200 | w_rec=1.0, w_kl=0.0000007, w_pred_prior=0.0200
# 2025-11-19 17:39:18,210 - INFO - Epoch 8, TRAIN: total=1.170e-02, 	rec=1.161e-02 (weighted=1.161e-02), 	kl=1.786e+01 (weighted=1.336e-05), 	pred_prior=4.086e-03 (weighted=8.172e-05),
# 2025-11-19 17:39:18,210 - INFO - EV Penalties: {}
# 2025-11-19 17:39:18,210 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:39:18,210 - INFO - ##############################
# 2025-11-19 17:39:18,210 - INFO - Epoch 9/1200 | w_rec=1.0, w_kl=0.0000010, w_pred_prior=0.0200
# 2025-11-19 17:39:22,109 - INFO - Epoch 9, TRAIN: total=1.078e-02, 	rec=1.069e-02 (weighted=1.069e-02), 	kl=1.726e+01 (weighted=1.686e-05), 	pred_prior=4.051e-03 (weighted=8.101e-05),
# 2025-11-19 17:39:22,109 - INFO - EV Penalties: {}
# 2025-11-19 17:39:22,109 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:39:22,109 - INFO - ##############################
# 2025-11-19 17:39:22,109 - INFO - Epoch 10/1200 | w_rec=1.0, w_kl=0.0000012, w_pred_prior=0.0200
# 2025-11-19 17:39:25,993 - INFO - Epoch 10, TRAIN: total=1.003e-02, 	rec=9.928e-03 (weighted=9.928e-03), 	kl=1.801e+01 (weighted=2.227e-05), 	pred_prior=4.074e-03 (weighted=8.148e-05),
# 2025-11-19 17:39:25,993 - INFO - EV Penalties: {}
# 2025-11-19 17:39:25,993 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:39:25,993 - INFO - ##############################
# 2025-11-19 17:39:25,993 - INFO - Epoch 11/1200 | w_rec=1.0, w_kl=0.0000015, w_pred_prior=0.0200
# 2025-11-19 17:39:29,964 - INFO - Epoch 11, TRAIN: total=9.048e-03, 	rec=8.936e-03 (weighted=8.936e-03), 	kl=1.814e+01 (weighted=2.768e-05), 	pred_prior=4.222e-03 (weighted=8.443e-05),
# 2025-11-19 17:39:29,964 - INFO - EV Penalties: {}
# 2025-11-19 17:39:29,964 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:39:29,964 - INFO - ##############################
# 2025-11-19 17:39:29,964 - INFO - Epoch 12/1200 | w_rec=1.0, w_kl=0.0000018, w_pred_prior=0.0200
# 2025-11-19 17:39:34,117 - INFO - Epoch 12, TRAIN: total=7.880e-03, 	rec=7.761e-03 (weighted=7.761e-03), 	kl=1.809e+01 (weighted=3.341e-05), 	pred_prior=4.264e-03 (weighted=8.528e-05),
# 2025-11-19 17:39:34,117 - INFO - EV Penalties: {}
# 2025-11-19 17:39:34,117 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:39:34,117 - INFO - ##############################
# 2025-11-19 17:39:34,117 - INFO - Epoch 13/1200 | w_rec=1.0, w_kl=0.0000022, w_pred_prior=0.0200
# 2025-11-19 17:39:38,021 - INFO - Epoch 13, TRAIN: total=7.230e-03, 	rec=7.103e-03 (weighted=7.103e-03), 	kl=1.754e+01 (weighted=3.855e-05), 	pred_prior=4.411e-03 (weighted=8.822e-05),
# 2025-11-19 17:39:38,021 - INFO - EV Penalties: {}
# 2025-11-19 17:39:38,021 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:39:38,021 - INFO - ##############################
# 2025-11-19 17:39:38,021 - INFO - Epoch 14/1200 | w_rec=1.0, w_kl=0.0000026, w_pred_prior=0.0200
# 2025-11-19 17:39:41,912 - INFO - Epoch 14, TRAIN: total=6.761e-03, 	rec=6.623e-03 (weighted=6.623e-03), 	kl=1.786e+01 (weighted=4.608e-05), 	pred_prior=4.582e-03 (weighted=9.165e-05),
# 2025-11-19 17:39:41,912 - INFO - EV Penalties: {}
# 2025-11-19 17:39:41,912 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:39:41,912 - INFO - ##############################
# 2025-11-19 17:39:41,912 - INFO - Epoch 15/1200 | w_rec=1.0, w_kl=0.0000030, w_pred_prior=0.0200
# 2025-11-19 17:39:45,791 - INFO - Epoch 15, TRAIN: total=6.472e-03, 	rec=6.328e-03 (weighted=6.328e-03), 	kl=1.720e+01 (weighted=5.144e-05), 	pred_prior=4.639e-03 (weighted=9.278e-05),
# 2025-11-19 17:39:45,791 - INFO - EV Penalties: {}
# 2025-11-19 17:39:45,791 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:39:45,791 - INFO - ##############################
# 2025-11-19 17:39:45,791 - INFO - Epoch 16/1200 | w_rec=1.0, w_kl=0.0000034, w_pred_prior=0.0200
# 2025-11-19 17:39:49,703 - INFO - Epoch 16, TRAIN: total=6.257e-03, 	rec=6.104e-03 (weighted=6.104e-03), 	kl=1.666e+01 (weighted=5.721e-05), 	pred_prior=4.831e-03 (weighted=9.662e-05),
# 2025-11-19 17:39:49,703 - INFO - EV Penalties: {}
# 2025-11-19 17:39:49,703 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:39:49,703 - INFO - ##############################
# 2025-11-19 17:39:49,703 - INFO - Epoch 17/1200 | w_rec=1.0, w_kl=0.0000039, w_pred_prior=0.0200
# 2025-11-19 17:39:53,696 - INFO - Epoch 17, TRAIN: total=6.175e-03, 	rec=6.014e-03 (weighted=6.014e-03), 	kl=1.605e+01 (weighted=6.269e-05), 	pred_prior=4.896e-03 (weighted=9.793e-05),
# 2025-11-19 17:39:53,696 - INFO - EV Penalties: {}
# 2025-11-19 17:39:53,696 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:39:53,696 - INFO - ##############################
# 2025-11-19 17:39:53,696 - INFO - Epoch 18/1200 | w_rec=1.0, w_kl=0.0000044, w_pred_prior=0.0200
# 2025-11-19 17:39:57,595 - INFO - Epoch 18, TRAIN: total=5.981e-03, 	rec=5.812e-03 (weighted=5.812e-03), 	kl=1.557e+01 (weighted=6.867e-05), 	pred_prior=5.051e-03 (weighted=1.010e-04),
# 2025-11-19 17:39:57,596 - INFO - EV Penalties: {}
# 2025-11-19 17:39:57,596 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:39:57,596 - INFO - ##############################
# 2025-11-19 17:39:57,596 - INFO - Epoch 19/1200 | w_rec=1.0, w_kl=0.0000049, w_pred_prior=0.0200
# 2025-11-19 17:40:01,565 - INFO - Epoch 19, TRAIN: total=5.873e-03, 	rec=5.696e-03 (weighted=5.696e-03), 	kl=1.475e+01 (weighted=7.291e-05), 	pred_prior=5.224e-03 (weighted=1.045e-04),
# 2025-11-19 17:40:01,565 - INFO - EV Penalties: {}
# 2025-11-19 17:40:01,565 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:40:01,565 - INFO - ##############################
# 2025-11-19 17:40:01,565 - INFO - Epoch 20/1200 | w_rec=1.0, w_kl=0.0000055, w_pred_prior=0.0200
# 2025-11-19 17:40:05,475 - INFO - Epoch 20, TRAIN: total=5.720e-03, 	rec=5.537e-03 (weighted=5.537e-03), 	kl=1.407e+01 (weighted=7.752e-05), 	pred_prior=5.303e-03 (weighted=1.061e-04),
# 2025-11-19 17:40:05,476 - INFO - EV Penalties: {}
# 2025-11-19 17:40:05,476 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:40:05,476 - INFO - ##############################
# 2025-11-19 17:40:05,476 - INFO - Epoch 21/1200 | w_rec=1.0, w_kl=0.0000061, w_pred_prior=0.0200
# 2025-11-19 17:40:09,526 - INFO - Epoch 21, TRAIN: total=5.598e-03, 	rec=5.406e-03 (weighted=5.406e-03), 	kl=1.364e+01 (weighted=8.327e-05), 	pred_prior=5.454e-03 (weighted=1.091e-04),
# 2025-11-19 17:40:09,527 - INFO - EV Penalties: {}
# 2025-11-19 17:40:09,527 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:40:09,527 - INFO - ##############################
# 2025-11-19 17:40:09,527 - INFO - Epoch 22/1200 | w_rec=1.0, w_kl=0.0000067, w_pred_prior=0.0200
# 2025-11-19 17:40:13,443 - INFO - Epoch 22, TRAIN: total=5.463e-03, 	rec=5.265e-03 (weighted=5.265e-03), 	kl=1.298e+01 (weighted=8.733e-05), 	pred_prior=5.534e-03 (weighted=1.107e-04),
# 2025-11-19 17:40:13,443 - INFO - EV Penalties: {}
# 2025-11-19 17:40:13,443 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:40:13,443 - INFO - ##############################
# 2025-11-19 17:40:13,443 - INFO - Epoch 23/1200 | w_rec=1.0, w_kl=0.0000074, w_pred_prior=0.0200
# 2025-11-19 17:40:17,411 - INFO - Epoch 23, TRAIN: total=5.347e-03, 	rec=5.141e-03 (weighted=5.141e-03), 	kl=1.248e+01 (weighted=9.217e-05), 	pred_prior=5.730e-03 (weighted=1.146e-04),
# 2025-11-19 17:40:17,411 - INFO - EV Penalties: {}
# 2025-11-19 17:40:17,411 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:40:17,411 - INFO - ##############################
# 2025-11-19 17:40:17,411 - INFO - Epoch 24/1200 | w_rec=1.0, w_kl=0.0000081, w_pred_prior=0.0200
# 2025-11-19 17:40:21,411 - INFO - Epoch 24, TRAIN: total=5.245e-03, 	rec=5.031e-03 (weighted=5.031e-03), 	kl=1.206e+01 (weighted=9.729e-05), 	pred_prior=5.812e-03 (weighted=1.162e-04),
# 2025-11-19 17:40:21,411 - INFO - EV Penalties: {}
# 2025-11-19 17:40:21,411 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:40:21,411 - INFO - ##############################
# 2025-11-19 17:40:21,411 - INFO - Epoch 25/1200 | w_rec=1.0, w_kl=0.0000088, w_pred_prior=0.0200
# 2025-11-19 17:40:25,347 - INFO - Epoch 25, TRAIN: total=5.144e-03, 	rec=4.923e-03 (weighted=4.923e-03), 	kl=1.170e+01 (weighted=1.028e-04), 	pred_prior=5.902e-03 (weighted=1.180e-04),
# 2025-11-19 17:40:25,347 - INFO - EV Penalties: {}
# 2025-11-19 17:40:25,347 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:40:25,347 - INFO - ##############################
# 2025-11-19 17:40:25,347 - INFO - Epoch 26/1200 | w_rec=1.0, w_kl=0.0000095, w_pred_prior=0.0200
# 2025-11-19 17:40:29,339 - INFO - Epoch 26, TRAIN: total=4.972e-03, 	rec=4.742e-03 (weighted=4.742e-03), 	kl=1.133e+01 (weighted=1.080e-04), 	pred_prior=6.063e-03 (weighted=1.213e-04),
# 2025-11-19 17:40:29,339 - INFO - EV Penalties: {}
# 2025-11-19 17:40:29,339 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:40:29,339 - INFO - ##############################
# 2025-11-19 17:40:29,339 - INFO - Epoch 27/1200 | w_rec=1.0, w_kl=0.0000103, w_pred_prior=0.0200
# 2025-11-19 17:40:33,231 - INFO - Epoch 27, TRAIN: total=4.916e-03, 	rec=4.681e-03 (weighted=4.681e-03), 	kl=1.093e+01 (weighted=1.127e-04), 	pred_prior=6.129e-03 (weighted=1.226e-04),
# 2025-11-19 17:40:33,231 - INFO - EV Penalties: {}
# 2025-11-19 17:40:33,231 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:40:33,231 - INFO - ##############################
# 2025-11-19 17:40:33,231 - INFO - Epoch 28/1200 | w_rec=1.0, w_kl=0.0000111, w_pred_prior=0.0200
# 2025-11-19 17:40:37,131 - INFO - Epoch 28, TRAIN: total=4.777e-03, 	rec=4.534e-03 (weighted=4.534e-03), 	kl=1.055e+01 (weighted=1.173e-04), 	pred_prior=6.279e-03 (weighted=1.256e-04),
# 2025-11-19 17:40:37,131 - INFO - EV Penalties: {}
# 2025-11-19 17:40:37,131 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:40:37,131 - INFO - ##############################
# 2025-11-19 17:40:37,131 - INFO - Epoch 29/1200 | w_rec=1.0, w_kl=0.0000120, w_pred_prior=0.0200
# 2025-11-19 17:40:41,104 - INFO - Epoch 29, TRAIN: total=4.682e-03, 	rec=4.429e-03 (weighted=4.429e-03), 	kl=1.037e+01 (weighted=1.240e-04), 	pred_prior=6.421e-03 (weighted=1.284e-04),
# 2025-11-19 17:40:41,104 - INFO - EV Penalties: {}
# 2025-11-19 17:40:41,105 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:40:41,105 - INFO - ##############################
# 2025-11-19 17:40:41,105 - INFO - Epoch 30/1200 | w_rec=1.0, w_kl=0.0000128, w_pred_prior=0.0200
# 2025-11-19 17:40:44,993 - INFO - Epoch 30, TRAIN: total=4.476e-03, 	rec=4.217e-03 (weighted=4.217e-03), 	kl=1.006e+01 (weighted=1.290e-04), 	pred_prior=6.525e-03 (weighted=1.305e-04),
# 2025-11-19 17:40:44,993 - INFO - EV Penalties: {}
# 2025-11-19 17:40:44,993 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:40:44,993 - INFO - ##############################
# 2025-11-19 17:40:44,993 - INFO - Epoch 31/1200 | w_rec=1.0, w_kl=0.0000137, w_pred_prior=0.0200
# 2025-11-19 17:40:48,881 - INFO - Epoch 31, TRAIN: total=4.238e-03, 	rec=3.972e-03 (weighted=3.972e-03), 	kl=9.753e+00 (weighted=1.339e-04), 	pred_prior=6.634e-03 (weighted=1.327e-04),
# 2025-11-19 17:40:48,881 - INFO - EV Penalties: {}
# 2025-11-19 17:40:48,881 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:40:48,881 - INFO - ##############################
# 2025-11-19 17:40:48,881 - INFO - Epoch 32/1200 | w_rec=1.0, w_kl=0.0000147, w_pred_prior=0.0200
# 2025-11-19 17:40:52,884 - INFO - Epoch 32, TRAIN: total=3.682e-03, 	rec=3.406e-03 (weighted=3.406e-03), 	kl=9.567e+00 (weighted=1.402e-04), 	pred_prior=6.756e-03 (weighted=1.351e-04),
# 2025-11-19 17:40:52,884 - INFO - EV Penalties: {}
# 2025-11-19 17:40:52,884 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:40:52,884 - INFO - ##############################
# 2025-11-19 17:40:52,884 - INFO - Epoch 33/1200 | w_rec=1.0, w_kl=0.0000156, w_pred_prior=0.0200
# 2025-11-19 17:40:56,806 - INFO - Epoch 33, TRAIN: total=3.152e-03, 	rec=2.868e-03 (weighted=2.868e-03), 	kl=9.430e+00 (weighted=1.472e-04), 	pred_prior=6.859e-03 (weighted=1.372e-04),
# 2025-11-19 17:40:56,807 - INFO - EV Penalties: {}
# 2025-11-19 17:40:56,807 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:40:56,807 - INFO - ##############################
# 2025-11-19 17:40:56,807 - INFO - Epoch 34/1200 | w_rec=1.0, w_kl=0.0000166, w_pred_prior=0.0200
# 2025-11-19 17:41:00,679 - INFO - Epoch 34, TRAIN: total=2.857e-03, 	rec=2.560e-03 (weighted=2.560e-03), 	kl=9.394e+00 (weighted=1.560e-04), 	pred_prior=7.038e-03 (weighted=1.408e-04),
# 2025-11-19 17:41:00,679 - INFO - EV Penalties: {}
# 2025-11-19 17:41:00,679 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:41:00,679 - INFO - ##############################
# 2025-11-19 17:41:00,679 - INFO - Epoch 35/1200 | w_rec=1.0, w_kl=0.0000176, w_pred_prior=0.0200
# 2025-11-19 17:41:04,992 - INFO - Epoch 35, TRAIN: total=2.678e-03, 	rec=2.371e-03 (weighted=2.371e-03), 	kl=9.281e+00 (weighted=1.636e-04), 	pred_prior=7.153e-03 (weighted=1.431e-04),
# 2025-11-19 17:41:04,993 - INFO - EV Penalties: {}
# 2025-11-19 17:41:04,993 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:41:04,993 - INFO - ##############################
# 2025-11-19 17:41:04,993 - INFO - Epoch 36/1200 | w_rec=1.0, w_kl=0.0000187, w_pred_prior=0.0200
# 2025-11-19 17:41:09,172 - INFO - Epoch 36, TRAIN: total=2.563e-03, 	rec=2.251e-03 (weighted=2.251e-03), 	kl=8.933e+00 (weighted=1.668e-04), 	pred_prior=7.236e-03 (weighted=1.447e-04),
# 2025-11-19 17:41:09,172 - INFO - EV Penalties: {}
# 2025-11-19 17:41:09,173 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:41:09,173 - INFO - ##############################
# 2025-11-19 17:41:09,173 - INFO - Epoch 37/1200 | w_rec=1.0, w_kl=0.0000198, w_pred_prior=0.0200
# 2025-11-19 17:41:13,224 - INFO - Epoch 37, TRAIN: total=2.448e-03, 	rec=2.127e-03 (weighted=2.127e-03), 	kl=8.822e+00 (weighted=1.743e-04), 	pred_prior=7.360e-03 (weighted=1.472e-04),
# 2025-11-19 17:41:13,224 - INFO - EV Penalties: {}
# 2025-11-19 17:41:13,224 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:41:13,224 - INFO - ##############################
# 2025-11-19 17:41:13,224 - INFO - Epoch 38/1200 | w_rec=1.0, w_kl=0.0000209, w_pred_prior=0.0200
# 2025-11-19 17:41:17,149 - INFO - Epoch 38, TRAIN: total=2.371e-03, 	rec=2.043e-03 (weighted=2.043e-03), 	kl=8.643e+00 (weighted=1.804e-04), 	pred_prior=7.419e-03 (weighted=1.484e-04),
# 2025-11-19 17:41:17,149 - INFO - EV Penalties: {}
# 2025-11-19 17:41:17,149 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:41:17,149 - INFO - ##############################
# 2025-11-19 17:41:17,149 - INFO - Epoch 39/1200 | w_rec=1.0, w_kl=0.0000220, w_pred_prior=0.0200
# 2025-11-19 17:41:21,103 - INFO - Epoch 39, TRAIN: total=2.304e-03, 	rec=1.966e-03 (weighted=1.966e-03), 	kl=8.456e+00 (weighted=1.861e-04), 	pred_prior=7.620e-03 (weighted=1.524e-04),
# 2025-11-19 17:41:21,103 - INFO - EV Penalties: {}
# 2025-11-19 17:41:21,103 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:41:21,103 - INFO - ##############################
# 2025-11-19 17:41:21,103 - INFO - Epoch 40/1200 | w_rec=1.0, w_kl=0.0000232, w_pred_prior=0.0200
# 2025-11-19 17:41:25,078 - INFO - Epoch 40, TRAIN: total=2.197e-03, 	rec=1.855e-03 (weighted=1.855e-03), 	kl=8.184e+00 (weighted=1.897e-04), 	pred_prior=7.641e-03 (weighted=1.528e-04),
# 2025-11-19 17:41:25,079 - INFO - EV Penalties: {}
# 2025-11-19 17:41:25,079 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:41:25,079 - INFO - ##############################
# 2025-11-19 17:41:25,079 - INFO - Epoch 41/1200 | w_rec=1.0, w_kl=0.0000244, w_pred_prior=0.0200
# 2025-11-19 17:41:28,972 - INFO - Epoch 41, TRAIN: total=2.145e-03, 	rec=1.792e-03 (weighted=1.792e-03), 	kl=8.133e+00 (weighted=1.983e-04), 	pred_prior=7.730e-03 (weighted=1.546e-04),
# 2025-11-19 17:41:28,972 - INFO - EV Penalties: {}
# 2025-11-19 17:41:28,972 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:41:28,972 - INFO - ##############################
# 2025-11-19 17:41:28,972 - INFO - Epoch 42/1200 | w_rec=1.0, w_kl=0.0000256, w_pred_prior=0.0200
# 2025-11-19 17:41:32,972 - INFO - Epoch 42, TRAIN: total=2.117e-03, 	rec=1.756e-03 (weighted=1.756e-03), 	kl=7.975e+00 (weighted=2.043e-04), 	pred_prior=7.859e-03 (weighted=1.572e-04),
# 2025-11-19 17:41:32,972 - INFO - EV Penalties: {}
# 2025-11-19 17:41:32,972 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:41:32,972 - INFO - ##############################
# 2025-11-19 17:41:32,972 - INFO - Epoch 43/1200 | w_rec=1.0, w_kl=0.0000269, w_pred_prior=0.0200
# 2025-11-19 17:41:36,981 - INFO - Epoch 43, TRAIN: total=2.069e-03, 	rec=1.703e-03 (weighted=1.703e-03), 	kl=7.717e+00 (weighted=2.074e-04), 	pred_prior=7.960e-03 (weighted=1.592e-04),
# 2025-11-19 17:41:36,981 - INFO - EV Penalties: {}
# 2025-11-19 17:41:36,982 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:41:36,982 - INFO - ##############################
# 2025-11-19 17:41:36,982 - INFO - Epoch 44/1200 | w_rec=1.0, w_kl=0.0000282, w_pred_prior=0.0200
# 2025-11-19 17:41:41,252 - INFO - Epoch 44, TRAIN: total=2.044e-03, 	rec=1.666e-03 (weighted=1.666e-03), 	kl=7.688e+00 (weighted=2.166e-04), 	pred_prior=8.057e-03 (weighted=1.611e-04),
# 2025-11-19 17:41:41,253 - INFO - EV Penalties: {}
# 2025-11-19 17:41:41,253 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:41:41,253 - INFO - ##############################
# 2025-11-19 17:41:41,253 - INFO - Epoch 45/1200 | w_rec=1.0, w_kl=0.0000295, w_pred_prior=0.0200
# 2025-11-19 17:41:45,167 - INFO - Epoch 45, TRAIN: total=1.992e-03, 	rec=1.609e-03 (weighted=1.609e-03), 	kl=7.483e+00 (weighted=2.207e-04), 	pred_prior=8.092e-03 (weighted=1.618e-04),
# 2025-11-19 17:41:45,167 - INFO - EV Penalties: {}
# 2025-11-19 17:41:45,167 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:41:45,167 - INFO - ##############################
# 2025-11-19 17:41:45,167 - INFO - Epoch 46/1200 | w_rec=1.0, w_kl=0.0000308, w_pred_prior=0.0200
# 2025-11-19 17:41:49,069 - INFO - Epoch 46, TRAIN: total=1.973e-03, 	rec=1.584e-03 (weighted=1.584e-03), 	kl=7.309e+00 (weighted=2.255e-04), 	pred_prior=8.185e-03 (weighted=1.637e-04),
# 2025-11-19 17:41:49,069 - INFO - EV Penalties: {}
# 2025-11-19 17:41:49,069 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:41:49,069 - INFO - ##############################
# 2025-11-19 17:41:49,069 - INFO - Epoch 47/1200 | w_rec=1.0, w_kl=0.0000322, w_pred_prior=0.0200
# 2025-11-19 17:41:53,024 - INFO - Epoch 47, TRAIN: total=1.947e-03, 	rec=1.550e-03 (weighted=1.550e-03), 	kl=7.182e+00 (weighted=2.315e-04), 	pred_prior=8.276e-03 (weighted=1.655e-04),
# 2025-11-19 17:41:53,024 - INFO - EV Penalties: {}
# 2025-11-19 17:41:53,024 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:41:53,024 - INFO - ##############################
# 2025-11-19 17:41:53,024 - INFO - Epoch 48/1200 | w_rec=1.0, w_kl=0.0000336, w_pred_prior=0.0200
# 2025-11-19 17:41:57,007 - INFO - Epoch 48, TRAIN: total=1.922e-03, 	rec=1.518e-03 (weighted=1.518e-03), 	kl=7.031e+00 (weighted=2.365e-04), 	pred_prior=8.336e-03 (weighted=1.667e-04),
# 2025-11-19 17:41:57,007 - INFO - EV Penalties: {}
# 2025-11-19 17:41:57,008 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:41:57,008 - INFO - ##############################
# 2025-11-19 17:41:57,008 - INFO - Epoch 49/1200 | w_rec=1.0, w_kl=0.0000351, w_pred_prior=0.0200
# 2025-11-19 17:42:01,033 - INFO - Epoch 49, TRAIN: total=1.943e-03, 	rec=1.537e-03 (weighted=1.537e-03), 	kl=6.799e+00 (weighted=2.385e-04), 	pred_prior=8.371e-03 (weighted=1.674e-04),
# 2025-11-19 17:42:01,033 - INFO - EV Penalties: {}
# 2025-11-19 17:42:01,033 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:42:01,033 - INFO - ##############################
# 2025-11-19 17:42:01,034 - INFO - Epoch 50/1200 | w_rec=1.0, w_kl=0.0000366, w_pred_prior=0.0200
# 2025-11-19 17:42:04,984 - INFO - Epoch 50, TRAIN: total=1.924e-03, 	rec=1.512e-03 (weighted=1.512e-03), 	kl=6.676e+00 (weighted=2.441e-04), 	pred_prior=8.395e-03 (weighted=1.679e-04),
# 2025-11-19 17:42:04,984 - INFO - EV Penalties: {}
# 2025-11-19 17:42:04,984 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:42:04,984 - INFO - ##############################
# 2025-11-19 17:42:04,984 - INFO - Epoch 51/1200 | w_rec=1.0, w_kl=0.0000381, w_pred_prior=0.0200
# 2025-11-19 17:42:08,906 - INFO - Epoch 51, TRAIN: total=1.885e-03, 	rec=1.466e-03 (weighted=1.466e-03), 	kl=6.565e+00 (weighted=2.499e-04), 	pred_prior=8.454e-03 (weighted=1.691e-04),
# 2025-11-19 17:42:08,906 - INFO - EV Penalties: {}
# 2025-11-19 17:42:08,906 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:42:08,907 - INFO - ##############################
# 2025-11-19 17:42:08,907 - INFO - Epoch 52/1200 | w_rec=1.0, w_kl=0.0000396, w_pred_prior=0.0200
# 2025-11-19 17:42:12,815 - INFO - Epoch 52, TRAIN: total=1.913e-03, 	rec=1.485e-03 (weighted=1.485e-03), 	kl=6.491e+00 (weighted=2.571e-04), 	pred_prior=8.558e-03 (weighted=1.712e-04),
# 2025-11-19 17:42:12,816 - INFO - EV Penalties: {}
# 2025-11-19 17:42:12,816 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:42:12,816 - INFO - ##############################
# 2025-11-19 17:42:12,816 - INFO - Epoch 53/1200 | w_rec=1.0, w_kl=0.0000412, w_pred_prior=0.0200
# 2025-11-19 17:42:16,716 - INFO - Epoch 53, TRAIN: total=1.879e-03, 	rec=1.446e-03 (weighted=1.446e-03), 	kl=6.348e+00 (weighted=2.613e-04), 	pred_prior=8.572e-03 (weighted=1.714e-04),
# 2025-11-19 17:42:16,716 - INFO - EV Penalties: {}
# 2025-11-19 17:42:16,716 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:42:16,716 - INFO - ##############################
# 2025-11-19 17:42:16,716 - INFO - Epoch 54/1200 | w_rec=1.0, w_kl=0.0000428, w_pred_prior=0.0200
# 2025-11-19 17:42:20,616 - INFO - Epoch 54, TRAIN: total=1.865e-03, 	rec=1.429e-03 (weighted=1.429e-03), 	kl=6.186e+00 (weighted=2.645e-04), 	pred_prior=8.592e-03 (weighted=1.718e-04),
# 2025-11-19 17:42:20,616 - INFO - EV Penalties: {}
# 2025-11-19 17:42:20,616 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:42:20,616 - INFO - ##############################
# 2025-11-19 17:42:20,616 - INFO - Epoch 55/1200 | w_rec=1.0, w_kl=0.0000444, w_pred_prior=0.0200
# 2025-11-19 17:42:24,799 - INFO - Epoch 55, TRAIN: total=1.867e-03, 	rec=1.426e-03 (weighted=1.426e-03), 	kl=6.086e+00 (weighted=2.701e-04), 	pred_prior=8.551e-03 (weighted=1.710e-04),
# 2025-11-19 17:42:24,799 - INFO - EV Penalties: {}
# 2025-11-19 17:42:24,799 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:42:24,799 - INFO - ##############################
# 2025-11-19 17:42:24,799 - INFO - Epoch 56/1200 | w_rec=1.0, w_kl=0.0000460, w_pred_prior=0.0200
# 2025-11-19 17:42:29,097 - INFO - Epoch 56, TRAIN: total=1.867e-03, 	rec=1.416e-03 (weighted=1.416e-03), 	kl=6.022e+00 (weighted=2.772e-04), 	pred_prior=8.685e-03 (weighted=1.737e-04),
# 2025-11-19 17:42:29,097 - INFO - EV Penalties: {}
# 2025-11-19 17:42:29,097 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:42:29,097 - INFO - ##############################
# 2025-11-19 17:42:29,097 - INFO - Epoch 57/1200 | w_rec=1.0, w_kl=0.0000477, w_pred_prior=0.0200
# 2025-11-19 17:42:33,545 - INFO - Epoch 57, TRAIN: total=1.871e-03, 	rec=1.415e-03 (weighted=1.415e-03), 	kl=5.893e+00 (weighted=2.812e-04), 	pred_prior=8.734e-03 (weighted=1.747e-04),
# 2025-11-19 17:42:33,545 - INFO - EV Penalties: {}
# 2025-11-19 17:42:33,545 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:42:33,545 - INFO - ##############################
# 2025-11-19 17:42:33,545 - INFO - Epoch 58/1200 | w_rec=1.0, w_kl=0.0000494, w_pred_prior=0.0200
# 2025-11-19 17:42:38,955 - INFO - Epoch 58, TRAIN: total=1.858e-03, 	rec=1.399e-03 (weighted=1.399e-03), 	kl=5.818e+00 (weighted=2.876e-04), 	pred_prior=8.615e-03 (weighted=1.723e-04),
# 2025-11-19 17:42:38,955 - INFO - EV Penalties: {}
# 2025-11-19 17:42:38,955 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:42:38,955 - INFO - ##############################
# 2025-11-19 17:42:38,955 - INFO - Epoch 59/1200 | w_rec=1.0, w_kl=0.0000512, w_pred_prior=0.0200
# 2025-11-19 17:42:43,047 - INFO - Epoch 59, TRAIN: total=1.820e-03, 	rec=1.358e-03 (weighted=1.358e-03), 	kl=5.622e+00 (weighted=2.877e-04), 	pred_prior=8.710e-03 (weighted=1.742e-04),
# 2025-11-19 17:42:43,048 - INFO - EV Penalties: {}
# 2025-11-19 17:42:43,048 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:42:43,048 - INFO - ##############################
# 2025-11-19 17:42:43,048 - INFO - Epoch 60/1200 | w_rec=1.0, w_kl=0.0000529, w_pred_prior=0.0200
# 2025-11-19 17:42:47,239 - INFO - Epoch 60, TRAIN: total=1.839e-03, 	rec=1.372e-03 (weighted=1.372e-03), 	kl=5.527e+00 (weighted=2.927e-04), 	pred_prior=8.727e-03 (weighted=1.745e-04),
# 2025-11-19 17:42:47,239 - INFO - EV Penalties: {}
# 2025-11-19 17:42:47,239 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:42:47,239 - INFO - ##############################
# 2025-11-19 17:42:47,239 - INFO - Epoch 61/1200 | w_rec=1.0, w_kl=0.0000548, w_pred_prior=0.0200
# 2025-11-19 17:42:51,603 - INFO - Epoch 61, TRAIN: total=1.921e-03, 	rec=1.434e-03 (weighted=1.434e-03), 	kl=5.678e+00 (weighted=3.109e-04), 	pred_prior=8.819e-03 (weighted=1.764e-04),
# 2025-11-19 17:42:51,603 - INFO - EV Penalties: {}
# 2025-11-19 17:42:51,603 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:42:51,603 - INFO - ##############################
# 2025-11-19 17:42:51,603 - INFO - Epoch 62/1200 | w_rec=1.0, w_kl=0.0000566, w_pred_prior=0.0200
# 2025-11-19 17:42:55,621 - INFO - Epoch 62, TRAIN: total=1.880e-03, 	rec=1.392e-03 (weighted=1.392e-03), 	kl=5.490e+00 (weighted=3.106e-04), 	pred_prior=8.904e-03 (weighted=1.781e-04),
# 2025-11-19 17:42:55,621 - INFO - EV Penalties: {}
# 2025-11-19 17:42:55,621 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:42:55,621 - INFO - ##############################
# 2025-11-19 17:42:55,621 - INFO - Epoch 63/1200 | w_rec=1.0, w_kl=0.0000584, w_pred_prior=0.0200
# 2025-11-19 17:42:59,709 - INFO - Epoch 63, TRAIN: total=1.875e-03, 	rec=1.375e-03 (weighted=1.375e-03), 	kl=5.524e+00 (weighted=3.229e-04), 	pred_prior=8.853e-03 (weighted=1.771e-04),
# 2025-11-19 17:42:59,709 - INFO - EV Penalties: {}
# 2025-11-19 17:42:59,709 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:42:59,709 - INFO - ##############################
# 2025-11-19 17:42:59,709 - INFO - Epoch 64/1200 | w_rec=1.0, w_kl=0.0000603, w_pred_prior=0.0200
# 2025-11-19 17:43:04,088 - INFO - Epoch 64, TRAIN: total=1.820e-03, 	rec=1.319e-03 (weighted=1.319e-03), 	kl=5.337e+00 (weighted=3.220e-04), 	pred_prior=8.944e-03 (weighted=1.789e-04),
# 2025-11-19 17:43:04,088 - INFO - EV Penalties: {}
# 2025-11-19 17:43:04,088 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:43:04,088 - INFO - ##############################
# 2025-11-19 17:43:04,088 - INFO - Epoch 65/1200 | w_rec=1.0, w_kl=0.0000623, w_pred_prior=0.0200
# 2025-11-19 17:43:08,797 - INFO - Epoch 65, TRAIN: total=1.812e-03, 	rec=1.316e-03 (weighted=1.316e-03), 	kl=5.121e+00 (weighted=3.189e-04), 	pred_prior=8.840e-03 (weighted=1.768e-04),
# 2025-11-19 17:43:08,798 - INFO - EV Penalties: {}
# 2025-11-19 17:43:08,798 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:43:08,798 - INFO - ##############################
# 2025-11-19 17:43:08,798 - INFO - Epoch 66/1200 | w_rec=1.0, w_kl=0.0000642, w_pred_prior=0.0200
# 2025-11-19 17:43:13,037 - INFO - Epoch 66, TRAIN: total=1.881e-03, 	rec=1.382e-03 (weighted=1.382e-03), 	kl=5.006e+00 (weighted=3.215e-04), 	pred_prior=8.890e-03 (weighted=1.778e-04),
# 2025-11-19 17:43:13,037 - INFO - EV Penalties: {}
# 2025-11-19 17:43:13,037 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:43:13,037 - INFO - ##############################
# 2025-11-19 17:43:13,037 - INFO - Epoch 67/1200 | w_rec=1.0, w_kl=0.0000662, w_pred_prior=0.0200
# 2025-11-19 17:43:17,348 - INFO - Epoch 67, TRAIN: total=1.827e-03, 	rec=1.310e-03 (weighted=1.310e-03), 	kl=5.092e+00 (weighted=3.371e-04), 	pred_prior=8.992e-03 (weighted=1.798e-04),
# 2025-11-19 17:43:17,348 - INFO - EV Penalties: {}
# 2025-11-19 17:43:17,348 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:43:17,348 - INFO - ##############################
# 2025-11-19 17:43:17,348 - INFO - Epoch 68/1200 | w_rec=1.0, w_kl=0.0000682, w_pred_prior=0.0200
# 2025-11-19 17:43:22,451 - INFO - Epoch 68, TRAIN: total=1.858e-03, 	rec=1.340e-03 (weighted=1.340e-03), 	kl=4.949e+00 (weighted=3.376e-04), 	pred_prior=8.978e-03 (weighted=1.796e-04),
# 2025-11-19 17:43:22,451 - INFO - EV Penalties: {}
# 2025-11-19 17:43:22,451 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:43:22,451 - INFO - ##############################
# 2025-11-19 17:43:22,451 - INFO - Epoch 69/1200 | w_rec=1.0, w_kl=0.0000703, w_pred_prior=0.0200
# 2025-11-19 17:43:27,045 - INFO - Epoch 69, TRAIN: total=1.822e-03, 	rec=1.295e-03 (weighted=1.295e-03), 	kl=4.923e+00 (weighted=3.459e-04), 	pred_prior=9.069e-03 (weighted=1.814e-04),
# 2025-11-19 17:43:27,045 - INFO - EV Penalties: {}
# 2025-11-19 17:43:27,045 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:43:27,045 - INFO - ##############################
# 2025-11-19 17:43:27,045 - INFO - Epoch 70/1200 | w_rec=1.0, w_kl=0.0000723, w_pred_prior=0.0200
# 2025-11-19 17:43:32,186 - INFO - Epoch 70, TRAIN: total=1.829e-03, 	rec=1.301e-03 (weighted=1.301e-03), 	kl=4.776e+00 (weighted=3.454e-04), 	pred_prior=9.130e-03 (weighted=1.826e-04),
# 2025-11-19 17:43:32,186 - INFO - EV Penalties: {}
# 2025-11-19 17:43:32,186 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:43:32,186 - INFO - ##############################
# 2025-11-19 17:43:32,186 - INFO - Epoch 71/1200 | w_rec=1.0, w_kl=0.0000744, w_pred_prior=0.0200
# 2025-11-19 17:43:37,280 - INFO - Epoch 71, TRAIN: total=1.802e-03, 	rec=1.269e-03 (weighted=1.269e-03), 	kl=4.713e+00 (weighted=3.508e-04), 	pred_prior=9.118e-03 (weighted=1.824e-04),
# 2025-11-19 17:43:37,280 - INFO - EV Penalties: {}
# 2025-11-19 17:43:37,280 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:43:37,280 - INFO - ##############################
# 2025-11-19 17:43:37,280 - INFO - Epoch 72/1200 | w_rec=1.0, w_kl=0.0000766, w_pred_prior=0.0200
# 2025-11-19 17:43:41,779 - INFO - Epoch 72, TRAIN: total=1.858e-03, 	rec=1.322e-03 (weighted=1.322e-03), 	kl=4.610e+00 (weighted=3.529e-04), 	pred_prior=9.179e-03 (weighted=1.836e-04),
# 2025-11-19 17:43:41,779 - INFO - EV Penalties: {}
# 2025-11-19 17:43:41,779 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:43:41,779 - INFO - ##############################
# 2025-11-19 17:43:41,779 - INFO - Epoch 73/1200 | w_rec=1.0, w_kl=0.0000787, w_pred_prior=0.0200
# 2025-11-19 17:43:46,284 - INFO - Epoch 73, TRAIN: total=1.831e-03, 	rec=1.290e-03 (weighted=1.290e-03), 	kl=4.550e+00 (weighted=3.581e-04), 	pred_prior=9.150e-03 (weighted=1.830e-04),
# 2025-11-19 17:43:46,284 - INFO - EV Penalties: {}
# 2025-11-19 17:43:46,284 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:43:46,284 - INFO - ##############################
# 2025-11-19 17:43:46,284 - INFO - Epoch 74/1200 | w_rec=1.0, w_kl=0.0000809, w_pred_prior=0.0200
# 2025-11-19 17:43:50,832 - INFO - Epoch 74, TRAIN: total=1.854e-03, 	rec=1.304e-03 (weighted=1.304e-03), 	kl=4.530e+00 (weighted=3.665e-04), 	pred_prior=9.201e-03 (weighted=1.840e-04),
# 2025-11-19 17:43:50,832 - INFO - EV Penalties: {}
# 2025-11-19 17:43:50,832 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:43:50,832 - INFO - ##############################
# 2025-11-19 17:43:50,832 - INFO - Epoch 75/1200 | w_rec=1.0, w_kl=0.0000831, w_pred_prior=0.0200
# 2025-11-19 17:43:55,439 - INFO - Epoch 75, TRAIN: total=1.803e-03, 	rec=1.243e-03 (weighted=1.243e-03), 	kl=4.491e+00 (weighted=3.733e-04), 	pred_prior=9.370e-03 (weighted=1.874e-04),
# 2025-11-19 17:43:55,440 - INFO - EV Penalties: {}
# 2025-11-19 17:43:55,440 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:43:55,440 - INFO - ##############################
# 2025-11-19 17:43:55,440 - INFO - Epoch 76/1200 | w_rec=1.0, w_kl=0.0000854, w_pred_prior=0.0200
# 2025-11-19 17:44:00,086 - INFO - Epoch 76, TRAIN: total=1.825e-03, 	rec=1.267e-03 (weighted=1.267e-03), 	kl=4.353e+00 (weighted=3.717e-04), 	pred_prior=9.316e-03 (weighted=1.863e-04),
# 2025-11-19 17:44:00,086 - INFO - EV Penalties: {}
# 2025-11-19 17:44:00,086 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:44:00,086 - INFO - ##############################
# 2025-11-19 17:44:00,086 - INFO - Epoch 77/1200 | w_rec=1.0, w_kl=0.0000877, w_pred_prior=0.0200
# 2025-11-19 17:44:04,777 - INFO - Epoch 77, TRAIN: total=1.852e-03, 	rec=1.289e-03 (weighted=1.289e-03), 	kl=4.310e+00 (weighted=3.778e-04), 	pred_prior=9.279e-03 (weighted=1.856e-04),
# 2025-11-19 17:44:04,777 - INFO - EV Penalties: {}
# 2025-11-19 17:44:04,777 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:44:04,777 - INFO - ##############################
# 2025-11-19 17:44:04,777 - INFO - Epoch 78/1200 | w_rec=1.0, w_kl=0.0000900, w_pred_prior=0.0200
# 2025-11-19 17:44:09,584 - INFO - Epoch 78, TRAIN: total=1.839e-03, 	rec=1.267e-03 (weighted=1.267e-03), 	kl=4.266e+00 (weighted=3.838e-04), 	pred_prior=9.410e-03 (weighted=1.882e-04),
# 2025-11-19 17:44:09,584 - INFO - EV Penalties: {}
# 2025-11-19 17:44:09,584 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:44:09,584 - INFO - ##############################
# 2025-11-19 17:44:09,584 - INFO - Epoch 79/1200 | w_rec=1.0, w_kl=0.0000923, w_pred_prior=0.0200
# 2025-11-19 17:44:14,326 - INFO - Epoch 79, TRAIN: total=1.858e-03, 	rec=1.278e-03 (weighted=1.278e-03), 	kl=4.224e+00 (weighted=3.898e-04), 	pred_prior=9.497e-03 (weighted=1.899e-04),
# 2025-11-19 17:44:14,326 - INFO - EV Penalties: {}
# 2025-11-19 17:44:14,326 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:44:14,326 - INFO - ##############################
# 2025-11-19 17:44:14,326 - INFO - Epoch 80/1200 | w_rec=1.0, w_kl=0.0000947, w_pred_prior=0.0200
# 2025-11-19 17:44:19,080 - INFO - Epoch 80, TRAIN: total=1.912e-03, 	rec=1.323e-03 (weighted=1.323e-03), 	kl=4.232e+00 (weighted=4.006e-04), 	pred_prior=9.411e-03 (weighted=1.882e-04),
# 2025-11-19 17:44:19,081 - INFO - EV Penalties: {}
# 2025-11-19 17:44:19,081 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:44:19,081 - INFO - ##############################
# 2025-11-19 17:44:19,081 - INFO - Epoch 81/1200 | w_rec=1.0, w_kl=0.0000971, w_pred_prior=0.0200
# 2025-11-19 17:44:23,932 - INFO - Epoch 81, TRAIN: total=1.853e-03, 	rec=1.260e-03 (weighted=1.260e-03), 	kl=4.138e+00 (weighted=4.016e-04), 	pred_prior=9.609e-03 (weighted=1.922e-04),
# 2025-11-19 17:44:23,932 - INFO - EV Penalties: {}
# 2025-11-19 17:44:23,932 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:44:23,932 - INFO - ##############################
# 2025-11-19 17:44:23,932 - INFO - Epoch 82/1200 | w_rec=1.0, w_kl=0.0000995, w_pred_prior=0.0200
# 2025-11-19 17:44:28,795 - INFO - Epoch 82, TRAIN: total=1.854e-03, 	rec=1.249e-03 (weighted=1.249e-03), 	kl=4.155e+00 (weighted=4.133e-04), 	pred_prior=9.550e-03 (weighted=1.910e-04),
# 2025-11-19 17:44:28,795 - INFO - EV Penalties: {}
# 2025-11-19 17:44:28,796 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:44:28,796 - INFO - ##############################
# 2025-11-19 17:44:28,796 - INFO - Epoch 83/1200 | w_rec=1.0, w_kl=0.0001019, w_pred_prior=0.0200
# 2025-11-19 17:44:33,676 - INFO - Epoch 83, TRAIN: total=1.847e-03, 	rec=1.243e-03 (weighted=1.243e-03), 	kl=4.030e+00 (weighted=4.108e-04), 	pred_prior=9.646e-03 (weighted=1.929e-04),
# 2025-11-19 17:44:33,676 - INFO - EV Penalties: {}
# 2025-11-19 17:44:33,676 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:44:33,676 - INFO - ##############################
# 2025-11-19 17:44:33,676 - INFO - Epoch 84/1200 | w_rec=1.0, w_kl=0.0001044, w_pred_prior=0.0200
# 2025-11-19 17:44:38,532 - INFO - Epoch 84, TRAIN: total=1.861e-03, 	rec=1.250e-03 (weighted=1.250e-03), 	kl=4.002e+00 (weighted=4.179e-04), 	pred_prior=9.667e-03 (weighted=1.933e-04),
# 2025-11-19 17:44:38,532 - INFO - EV Penalties: {}
# 2025-11-19 17:44:38,532 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:44:38,532 - INFO - ##############################
# 2025-11-19 17:44:38,533 - INFO - Epoch 85/1200 | w_rec=1.0, w_kl=0.0001069, w_pred_prior=0.0200
# 2025-11-19 17:44:43,474 - INFO - Epoch 85, TRAIN: total=1.838e-03, 	rec=1.226e-03 (weighted=1.226e-03), 	kl=3.905e+00 (weighted=4.176e-04), 	pred_prior=9.721e-03 (weighted=1.944e-04),
# 2025-11-19 17:44:43,474 - INFO - EV Penalties: {}
# 2025-11-19 17:44:43,474 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:44:43,474 - INFO - ##############################
# 2025-11-19 17:44:43,474 - INFO - Epoch 86/1200 | w_rec=1.0, w_kl=0.0001095, w_pred_prior=0.0200
# 2025-11-19 17:44:48,502 - INFO - Epoch 86, TRAIN: total=1.843e-03, 	rec=1.233e-03 (weighted=1.233e-03), 	kl=3.814e+00 (weighted=4.176e-04), 	pred_prior=9.634e-03 (weighted=1.927e-04),
# 2025-11-19 17:44:48,503 - INFO - EV Penalties: {}
# 2025-11-19 17:44:48,503 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:44:48,503 - INFO - ##############################
# 2025-11-19 17:44:48,503 - INFO - Epoch 87/1200 | w_rec=1.0, w_kl=0.0001121, w_pred_prior=0.0200
# 2025-11-19 17:44:53,294 - INFO - Epoch 87, TRAIN: total=1.863e-03, 	rec=1.248e-03 (weighted=1.248e-03), 	kl=3.759e+00 (weighted=4.212e-04), 	pred_prior=9.732e-03 (weighted=1.946e-04),
# 2025-11-19 17:44:53,295 - INFO - EV Penalties: {}
# 2025-11-19 17:44:53,295 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:44:53,295 - INFO - ##############################
# 2025-11-19 17:44:53,295 - INFO - Epoch 88/1200 | w_rec=1.0, w_kl=0.0001147, w_pred_prior=0.0200
# 2025-11-19 17:44:58,213 - INFO - Epoch 88, TRAIN: total=1.900e-03, 	rec=1.278e-03 (weighted=1.278e-03), 	kl=3.724e+00 (weighted=4.270e-04), 	pred_prior=9.718e-03 (weighted=1.944e-04),
# 2025-11-19 17:44:58,213 - INFO - EV Penalties: {}
# 2025-11-19 17:44:58,213 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:44:58,213 - INFO - ##############################
# 2025-11-19 17:44:58,213 - INFO - Epoch 89/1200 | w_rec=1.0, w_kl=0.0001173, w_pred_prior=0.0200
# 2025-11-19 17:45:03,128 - INFO - Epoch 89, TRAIN: total=1.879e-03, 	rec=1.241e-03 (weighted=1.241e-03), 	kl=3.770e+00 (weighted=4.421e-04), 	pred_prior=9.795e-03 (weighted=1.959e-04),
# 2025-11-19 17:45:03,128 - INFO - EV Penalties: {}
# 2025-11-19 17:45:03,129 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:45:03,129 - INFO - ##############################
# 2025-11-19 17:45:03,129 - INFO - Epoch 90/1200 | w_rec=1.0, w_kl=0.0001199, w_pred_prior=0.0200
# 2025-11-19 17:45:08,103 - INFO - Epoch 90, TRAIN: total=1.842e-03, 	rec=1.211e-03 (weighted=1.211e-03), 	kl=3.622e+00 (weighted=4.344e-04), 	pred_prior=9.817e-03 (weighted=1.963e-04),
# 2025-11-19 17:45:08,103 - INFO - EV Penalties: {}
# 2025-11-19 17:45:08,103 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:45:08,103 - INFO - ##############################
# 2025-11-19 17:45:08,103 - INFO - Epoch 91/1200 | w_rec=1.0, w_kl=0.0001226, w_pred_prior=0.0200
# 2025-11-19 17:45:13,199 - INFO - Epoch 91, TRAIN: total=1.861e-03, 	rec=1.230e-03 (weighted=1.230e-03), 	kl=3.555e+00 (weighted=4.359e-04), 	pred_prior=9.760e-03 (weighted=1.952e-04),
# 2025-11-19 17:45:13,200 - INFO - EV Penalties: {}
# 2025-11-19 17:45:13,200 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:45:13,200 - INFO - ##############################
# 2025-11-19 17:45:13,200 - INFO - Epoch 92/1200 | w_rec=1.0, w_kl=0.0001253, w_pred_prior=0.0200
# 2025-11-19 17:45:18,292 - INFO - Epoch 92, TRAIN: total=1.869e-03, 	rec=1.227e-03 (weighted=1.227e-03), 	kl=3.559e+00 (weighted=4.461e-04), 	pred_prior=9.773e-03 (weighted=1.955e-04),
# 2025-11-19 17:45:18,292 - INFO - EV Penalties: {}
# 2025-11-19 17:45:18,292 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:45:18,292 - INFO - ##############################
# 2025-11-19 17:45:18,292 - INFO - Epoch 93/1200 | w_rec=1.0, w_kl=0.0001281, w_pred_prior=0.0200
# 2025-11-19 17:45:23,563 - INFO - Epoch 93, TRAIN: total=1.865e-03, 	rec=1.227e-03 (weighted=1.227e-03), 	kl=3.475e+00 (weighted=4.451e-04), 	pred_prior=9.678e-03 (weighted=1.936e-04),
# 2025-11-19 17:45:23,564 - INFO - EV Penalties: {}
# 2025-11-19 17:45:23,564 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:45:23,564 - INFO - ##############################
# 2025-11-19 17:45:23,564 - INFO - Epoch 94/1200 | w_rec=1.0, w_kl=0.0001309, w_pred_prior=0.0200
# 2025-11-19 17:45:28,750 - INFO - Epoch 94, TRAIN: total=1.842e-03, 	rec=1.197e-03 (weighted=1.197e-03), 	kl=3.434e+00 (weighted=4.494e-04), 	pred_prior=9.740e-03 (weighted=1.948e-04),
# 2025-11-19 17:45:28,750 - INFO - EV Penalties: {}
# 2025-11-19 17:45:28,750 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:45:28,750 - INFO - ##############################
# 2025-11-19 17:45:28,750 - INFO - Epoch 95/1200 | w_rec=1.0, w_kl=0.0001337, w_pred_prior=0.0200
# 2025-11-19 17:45:33,929 - INFO - Epoch 95, TRAIN: total=1.845e-03, 	rec=1.209e-03 (weighted=1.209e-03), 	kl=3.317e+00 (weighted=4.434e-04), 	pred_prior=9.627e-03 (weighted=1.925e-04),
# 2025-11-19 17:45:33,929 - INFO - EV Penalties: {}
# 2025-11-19 17:45:33,929 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:45:33,929 - INFO - ##############################
# 2025-11-19 17:45:33,929 - INFO - Epoch 96/1200 | w_rec=1.0, w_kl=0.0001365, w_pred_prior=0.0200
# 2025-11-19 17:45:39,817 - INFO - Epoch 96, TRAIN: total=1.860e-03, 	rec=1.217e-03 (weighted=1.217e-03), 	kl=3.292e+00 (weighted=4.494e-04), 	pred_prior=9.693e-03 (weighted=1.939e-04),
# 2025-11-19 17:45:39,817 - INFO - EV Penalties: {}
# 2025-11-19 17:45:39,817 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:45:39,817 - INFO - ##############################
# 2025-11-19 17:45:39,818 - INFO - Epoch 97/1200 | w_rec=1.0, w_kl=0.0001394, w_pred_prior=0.0200
# 2025-11-19 17:45:45,504 - INFO - Epoch 97, TRAIN: total=1.885e-03, 	rec=1.233e-03 (weighted=1.233e-03), 	kl=3.280e+00 (weighted=4.571e-04), 	pred_prior=9.722e-03 (weighted=1.944e-04),
# 2025-11-19 17:45:45,504 - INFO - EV Penalties: {}
# 2025-11-19 17:45:45,504 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:45:45,504 - INFO - ##############################
# 2025-11-19 17:45:45,504 - INFO - Epoch 98/1200 | w_rec=1.0, w_kl=0.0001423, w_pred_prior=0.0200
# 2025-11-19 17:45:51,077 - INFO - Epoch 98, TRAIN: total=1.854e-03, 	rec=1.201e-03 (weighted=1.201e-03), 	kl=3.230e+00 (weighted=4.595e-04), 	pred_prior=9.648e-03 (weighted=1.930e-04),
# 2025-11-19 17:45:51,077 - INFO - EV Penalties: {}
# 2025-11-19 17:45:51,077 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:45:51,077 - INFO - ##############################
# 2025-11-19 17:45:51,077 - INFO - Epoch 99/1200 | w_rec=1.0, w_kl=0.0001452, w_pred_prior=0.0200
# 2025-11-19 17:45:56,865 - INFO - Epoch 99, TRAIN: total=1.940e-03, 	rec=1.289e-03 (weighted=1.289e-03), 	kl=3.177e+00 (weighted=4.612e-04), 	pred_prior=9.486e-03 (weighted=1.897e-04),
# 2025-11-19 17:45:56,865 - INFO - EV Penalties: {}
# 2025-11-19 17:45:56,865 - INFO - EV Penalties (weighted): {}
# 2025-11-19 17:45:56,865 - INFO - ##############################
# 2025-11-19 17:45:56,865 - INFO - Epoch 100/1200 | w_rec=1.0, w_kl=0.0001481, w_pred_prior=0.0200
# 2025-11-19 17:46:02,240 - INFO - Epoch 100, TRAIN: total=1.905e-03, 	rec=1.221e-03 (weighted=1.221e-03), 	kl=3.295e+00 (weighted=4.881e-04), 	pred_prior=9.779e-03 (weighted=1.956e-04),
# ...
# 2025-11-19 19:22:24,249 - INFO - EV Penalties: {}
# 2025-11-19 19:22:24,249 - INFO - EV Penalties (weighted): {}
# 2025-11-19 19:22:24,249 - INFO - ##############################
# 2025-11-19 19:22:24,249 - INFO - Epoch 1189/1200 | w_rec=1.0, w_kl=0.0050000, w_pred_prior=0.0200
# 2025-11-19 19:22:29,302 - INFO - Epoch 1189, TRAIN: total=5.530e-03, 	rec=1.870e-03 (weighted=1.870e-03), 	kl=6.998e-01 (weighted=3.499e-03), 	pred_prior=8.051e-03 (weighted=1.610e-04),
# 2025-11-19 19:22:29,302 - INFO - EV Penalties: {}
# 2025-11-19 19:22:29,302 - INFO - EV Penalties (weighted): {}
# 2025-11-19 19:22:29,302 - INFO - ##############################
# 2025-11-19 19:22:29,302 - INFO - Epoch 1190/1200 | w_rec=1.0, w_kl=0.0050000, w_pred_prior=0.0200
# 2025-11-19 19:22:34,310 - INFO - Epoch 1190, TRAIN: total=5.627e-03, 	rec=1.944e-03 (weighted=1.944e-03), 	kl=7.044e-01 (weighted=3.522e-03), 	pred_prior=8.036e-03 (weighted=1.607e-04),
# 2025-11-19 19:22:34,310 - INFO - EV Penalties: {}
# 2025-11-19 19:22:34,310 - INFO - EV Penalties (weighted): {}
# 2025-11-19 19:22:34,310 - INFO - ##############################
# 2025-11-19 19:22:34,310 - INFO - Epoch 1191/1200 | w_rec=1.0, w_kl=0.0050000, w_pred_prior=0.0200
# 2025-11-19 19:22:39,588 - INFO - Epoch 1191, TRAIN: total=5.603e-03, 	rec=1.877e-03 (weighted=1.877e-03), 	kl=7.131e-01 (weighted=3.566e-03), 	pred_prior=8.053e-03 (weighted=1.611e-04),
# 2025-11-19 19:22:39,589 - INFO - EV Penalties: {}
# 2025-11-19 19:22:39,589 - INFO - EV Penalties (weighted): {}
# 2025-11-19 19:22:39,589 - INFO - ##############################
# 2025-11-19 19:22:39,589 - INFO - Epoch 1192/1200 | w_rec=1.0, w_kl=0.0050000, w_pred_prior=0.0200
# 2025-11-19 19:22:44,689 - INFO - Epoch 1192, TRAIN: total=5.616e-03, 	rec=1.901e-03 (weighted=1.901e-03), 	kl=7.106e-01 (weighted=3.553e-03), 	pred_prior=8.069e-03 (weighted=1.614e-04),
# 2025-11-19 19:22:44,689 - INFO - EV Penalties: {}
# 2025-11-19 19:22:44,690 - INFO - EV Penalties (weighted): {}
# 2025-11-19 19:22:44,690 - INFO - ##############################
# 2025-11-19 19:22:44,690 - INFO - Epoch 1193/1200 | w_rec=1.0, w_kl=0.0050000, w_pred_prior=0.0200
# 2025-11-19 19:22:49,769 - INFO - Epoch 1193, TRAIN: total=5.575e-03, 	rec=1.898e-03 (weighted=1.898e-03), 	kl=7.032e-01 (weighted=3.516e-03), 	pred_prior=8.062e-03 (weighted=1.612e-04),
# 2025-11-19 19:22:49,769 - INFO - EV Penalties: {}
# 2025-11-19 19:22:49,769 - INFO - EV Penalties (weighted): {}
# 2025-11-19 19:22:49,769 - INFO - ##############################
# 2025-11-19 19:22:49,769 - INFO - Epoch 1194/1200 | w_rec=1.0, w_kl=0.0050000, w_pred_prior=0.0200
# 2025-11-19 19:22:54,819 - INFO - Epoch 1194, TRAIN: total=5.617e-03, 	rec=1.918e-03 (weighted=1.918e-03), 	kl=7.075e-01 (weighted=3.538e-03), 	pred_prior=8.042e-03 (weighted=1.608e-04),
# 2025-11-19 19:22:54,820 - INFO - EV Penalties: {}
# 2025-11-19 19:22:54,820 - INFO - EV Penalties (weighted): {}
# 2025-11-19 19:22:54,820 - INFO - ##############################
# 2025-11-19 19:22:54,820 - INFO - Epoch 1195/1200 | w_rec=1.0, w_kl=0.0050000, w_pred_prior=0.0200
# 2025-11-19 19:22:59,915 - INFO - Epoch 1195, TRAIN: total=5.561e-03, 	rec=1.860e-03 (weighted=1.860e-03), 	kl=7.080e-01 (weighted=3.540e-03), 	pred_prior=8.065e-03 (weighted=1.613e-04),
# 2025-11-19 19:22:59,915 - INFO - EV Penalties: {}
# 2025-11-19 19:22:59,915 - INFO - EV Penalties (weighted): {}
# 2025-11-19 19:22:59,915 - INFO - ##############################
# 2025-11-19 19:22:59,915 - INFO - Epoch 1196/1200 | w_rec=1.0, w_kl=0.0050000, w_pred_prior=0.0200
# 2025-11-19 19:23:05,002 - INFO - Epoch 1196, TRAIN: total=5.480e-03, 	rec=1.819e-03 (weighted=1.819e-03), 	kl=7.000e-01 (weighted=3.500e-03), 	pred_prior=8.024e-03 (weighted=1.605e-04),
# 2025-11-19 19:23:05,002 - INFO - EV Penalties: {}
# 2025-11-19 19:23:05,002 - INFO - EV Penalties (weighted): {}
# 2025-11-19 19:23:05,002 - INFO - ##############################
# 2025-11-19 19:23:05,002 - INFO - Epoch 1197/1200 | w_rec=1.0, w_kl=0.0050000, w_pred_prior=0.0200
# 2025-11-19 19:23:10,189 - INFO - Epoch 1197, TRAIN: total=5.499e-03, 	rec=1.864e-03 (weighted=1.864e-03), 	kl=6.954e-01 (weighted=3.477e-03), 	pred_prior=7.923e-03 (weighted=1.585e-04),
# 2025-11-19 19:23:10,189 - INFO - EV Penalties: {}
# 2025-11-19 19:23:10,189 - INFO - EV Penalties (weighted): {}
# 2025-11-19 19:23:10,189 - INFO - ##############################
# 2025-11-19 19:23:10,189 - INFO - Epoch 1198/1200 | w_rec=1.0, w_kl=0.0050000, w_pred_prior=0.0200
# 2025-11-19 19:23:15,286 - INFO - Epoch 1198, TRAIN: total=5.522e-03, 	rec=1.884e-03 (weighted=1.884e-03), 	kl=6.956e-01 (weighted=3.478e-03), 	pred_prior=8.001e-03 (weighted=1.600e-04),
# 2025-11-19 19:23:15,286 - INFO - EV Penalties: {}
# 2025-11-19 19:23:15,287 - INFO - EV Penalties (weighted): {}
# 2025-11-19 19:23:15,287 - INFO - ##############################
# 2025-11-19 19:23:15,287 - INFO - Epoch 1199/1200 | w_rec=1.0, w_kl=0.0050000, w_pred_prior=0.0200
# 2025-11-19 19:23:20,448 - INFO - Epoch 1199, TRAIN: total=5.500e-03, 	rec=1.837e-03 (weighted=1.837e-03), 	kl=7.003e-01 (weighted=3.502e-03), 	pred_prior=8.041e-03 (weighted=1.608e-04),
# 2025-11-19 19:23:20,448 - INFO - EV Penalties: {}
# 2025-11-19 19:23:20,448 - INFO - EV Penalties (weighted): {}
# 2025-11-19 19:23:20,448 - INFO - ##############################
# 2025-11-19 19:23:20,448 - INFO - Epoch 1200/1200 | w_rec=1.0, w_kl=0.0050000, w_pred_prior=0.0200
# 2025-11-19 19:23:25,671 - INFO - Epoch 1200, TRAIN: total=5.622e-03, 	rec=1.911e-03 (weighted=1.911e-03), 	kl=7.099e-01 (weighted=3.549e-03), 	pred_prior=8.066e-03 (weighted=1.613e-04),
# 2025-11-19 19:23:25,671 - INFO - EV Penalties: {}
# 2025-11-19 19:23:25,671 - INFO - EV Penalties (weighted): {}
# 2025-11-19 19:23:25,671 - INFO - ##############################
# 2025-11-19 19:23:25,671 - INFO - Generating outputs and visualizations at epoch 1200
# 2025-11-19 19:23:26,244 - INFO - Generated data saved into ./Generated_data/epoch_1200
# 2025-11-19 19:23:27,548 - INFO - Reconstructed data saved into ./Generated_data/epoch_1200
# 2025-11-19 19:23:27,788 - INFO - Original data saved into ./Generated_data/epoch_1200
# 2025-11-19 19:23:37,466 - INFO - Training is complete
# test/disc_mean:  0.5
# test/disc_std:  0.0
# ----------------------------------------
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:71: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   p_cell = tf.compat.v1.nn.rnn_cell.GRUCell(num_units=hidden_dim, activation=tf.nn.tanh, name = 'p_cell')
# WARNING:tensorflow:From /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# 2025-11-19 19:28:23,826 - WARNING - From /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:72: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /home/dauin_user/fleone/env/lib/python3.9/site-packages/keras/layers/rnn/legacy_cells.py:584: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 2025-11-19 19:28:24,110 - WARNING - From /home/dauin_user/fleone/env/lib/python3.9/site-packages/keras/layers/rnn/legacy_cells.py:584: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/dauin_user/fleone/env/lib/python3.9/site-packages/keras/layers/rnn/legacy_cells.py:598: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# 2025-11-19 19:28:24,126 - WARNING - From /home/dauin_user/fleone/env/lib/python3.9/site-packages/keras/layers/rnn/legacy_cells.py:598: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:73: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   y_hat_logit = tf.compat.v1.layers.dense(p_outputs, 1, activation=None)
# WARNING:tensorflow:From /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:75: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# 2025-11-19 19:28:24,220 - WARNING - From /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:75: all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Please use tf.global_variables instead.
# 2025-11-19 19:28:24.606837: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:353] MLIR V1 optimization pass is not enabled
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:71: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   p_cell = tf.compat.v1.nn.rnn_cell.GRUCell(num_units=hidden_dim, activation=tf.nn.tanh, name = 'p_cell')
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:73: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   y_hat_logit = tf.compat.v1.layers.dense(p_outputs, 1, activation=None)
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:71: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   p_cell = tf.compat.v1.nn.rnn_cell.GRUCell(num_units=hidden_dim, activation=tf.nn.tanh, name = 'p_cell')
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:73: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   y_hat_logit = tf.compat.v1.layers.dense(p_outputs, 1, activation=None)
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:71: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   p_cell = tf.compat.v1.nn.rnn_cell.GRUCell(num_units=hidden_dim, activation=tf.nn.tanh, name = 'p_cell')
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:73: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   y_hat_logit = tf.compat.v1.layers.dense(p_outputs, 1, activation=None)
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:71: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   p_cell = tf.compat.v1.nn.rnn_cell.GRUCell(num_units=hidden_dim, activation=tf.nn.tanh, name = 'p_cell')
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:73: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   y_hat_logit = tf.compat.v1.layers.dense(p_outputs, 1, activation=None)
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:71: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   p_cell = tf.compat.v1.nn.rnn_cell.GRUCell(num_units=hidden_dim, activation=tf.nn.tanh, name = 'p_cell')
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:73: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   y_hat_logit = tf.compat.v1.layers.dense(p_outputs, 1, activation=None)
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:71: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   p_cell = tf.compat.v1.nn.rnn_cell.GRUCell(num_units=hidden_dim, activation=tf.nn.tanh, name = 'p_cell')
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:73: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   y_hat_logit = tf.compat.v1.layers.dense(p_outputs, 1, activation=None)
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:71: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   p_cell = tf.compat.v1.nn.rnn_cell.GRUCell(num_units=hidden_dim, activation=tf.nn.tanh, name = 'p_cell')
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:73: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   y_hat_logit = tf.compat.v1.layers.dense(p_outputs, 1, activation=None)
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:71: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   p_cell = tf.compat.v1.nn.rnn_cell.GRUCell(num_units=hidden_dim, activation=tf.nn.tanh, name = 'p_cell')
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:73: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   y_hat_logit = tf.compat.v1.layers.dense(p_outputs, 1, activation=None)
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:71: UserWarning: `tf.nn.rnn_cell.GRUCell` is deprecated and will be removed in a future version. This class is equivalent as `tf.keras.layers.GRUCell`, and will be replaced by that in Tensorflow 2.0.
#   p_cell = tf.compat.v1.nn.rnn_cell.GRUCell(num_units=hidden_dim, activation=tf.nn.tanh, name = 'p_cell')
# /home/dauin_user/fleone/KoVAE/metrics/predictive_metrics.py:73: UserWarning: `tf.layers.dense` is deprecated and will be removed in a future version. Please use `tf.keras.layers.Dense` instead.
#   y_hat_logit = tf.compat.v1.layers.dense(p_outputs, 1, activation=None)
# test/pred_mean:  10.9908
# test/pred_std:  0.0592
# ----------------------------------------
# Figure(640x480)
# [t-SNE] Computing 121 nearest neighbors...
# [t-SNE] Indexed 2000 samples in 0.008s...
# [t-SNE] Computed neighbors for 2000 samples in 0.269s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 2000
# [t-SNE] Computed conditional probabilities for sample 2000 / 2000
# [t-SNE] Mean sigma: 25.255297
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 71.411644
# [t-SNE] KL divergence after 300 iterations: 1.516231
# Figure(640x480)

# %%
##################### TO RUN ONLY AFTER A WRONG EXECUTION OF THE PREVIOUS CELL ################
# !rm -rf datasets/EV0.3/ datasets/stock0.3/ Generated_data/ Output_info/ visualizations/
